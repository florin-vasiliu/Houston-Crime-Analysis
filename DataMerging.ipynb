# %%
import pandas as pd

# %%
houston_weather = pd.read_csv('Luis/houston_weather.csv')
crime_data = pd.read_csv('data_clean_up/Full_Crimes_CSV.csv')
# Out:
# C:\Users\favas\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
houston_weather = houston_weather.rename(columns={"Hour_Beginning":"Hour"})
houston_weather.head()
# Out:
#    Unnamed: 0            Date_Time        Date  Year  Month  Week_Num  Day  \
# 0           0  2018-01-01 00:00:00  2018-01-01  2018      1         1    1
# 1           1  2018-01-01 01:00:00  2018-01-01  2018      1         1    1
# 2           2  2018-01-01 02:00:00  2018-01-01  2018      1         1    1
# 3           3  2018-01-01 03:00:00  2018-01-01  2018      1         1    1
# 4           4  2018-01-01 04:00:00  2018-01-01  2018      1         1    1
#
#    Hour Day_of_Week  Temperature  Precipitation Weather Weather_Description
# 0     0      Monday        46.56            0.0  Clouds     overcast clouds
# 1     1      Monday        46.40            0.0  Clouds     overcast clouds
# 2     2      Monday        45.07            0.0  Clouds     overcast clouds
# 3     3      Monday        43.90            0.0  Clouds     overcast clouds
# 4     4      Monday        41.40            0.0  Clouds       broken clouds

# %%
crime_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Date  Hour Offense_Type  Offense_Count  \
# 0           0             0  1/1/20   0.0        Theft            1.0
# 1           1             1  1/1/20   0.0      Assault            1.0
# 2           2             2  1/1/20   0.0    Vandalism            1.0
# 3           3             3  1/1/20   0.0      Assault            1.0
# 4           4             4  1/1/20   0.0    Vandalism            1.0
#
#                                 Premise Block_Range Street_Name Street_Type  \
# 0  Residence, Home (Includes Apartment)        9311  BELLA PINE          CT
# 1  Residence, Home (Includes Apartment)        8701     GUSTINE          LN
# 2  Residence, Home (Includes Apartment)        8064      LENORE         NaN
# 3  Residence, Home (Includes Apartment)        5930    DASHWOOD          DR
# 4  Residence, Home (Includes Apartment)        5218   KENILWOOD          DR
#
#       City State      Street_Address  Zip_Code  \
# 0  Houston    TX  9311+BELLA+PINE+CT       NaN
# 1  Houston    TX     8701+GUSTINE+LN       NaN
# 2  Houston    TX        8064+LENORE+       NaN
# 3  Houston    TX    5930+DASHWOOD+DR       NaN
# 4  Houston    TX   5218+KENILWOOD+DR       NaN
#
#                       Full_Address   Latitude  Longitude     Tract
# 0  9311 BELLA PINE CT, Houston, TX  29.856285 -95.251628  231200.0
# 1     8701 GUSTINE LN, Houston, TX  29.669442 -95.532628  423202.0
# 2        8064 LENORE , Houston, TX  29.676495 -95.263450  320602.0
# 3    5930 DASHWOOD DR, Houston, TX  29.707437 -95.485750  421403.0
# 4   5218 KENILWOOD DR, Houston, TX  29.672524 -95.344034  332000.0

# %%
#sort crime df
crime_data = crime_data.sort_values(["Date", "Hour"])

#delete unecessary columns
del crime_data["Unnamed: 0"]
del crime_data["Unnamed: 0.1"]
del crime_data["Zip_Code"]

crime_data['Tract'] = crime_data['Tract'].apply(lambda f: format(f, '.0f'))

# %%
crime_data['Year'] = pd.DatetimeIndex(crime_data['Date']).year
crime_data['Month'] = pd.DatetimeIndex(crime_data['Date']).month
crime_data['Day'] = pd.DatetimeIndex(crime_data['Date']).day

# %%
crime_data.reset_index(drop=True)
# Out:
#               Date  Hour      Offense_Type  Offense_Count  \
# 0       01/01/2018   0.0  Burglary/Robbery            1.0
# 1       01/01/2018   0.0  Burglary/Robbery            1.0
# 2       01/01/2018   0.0  Burglary/Robbery            1.0
# 3       01/01/2018   0.0           Assault            2.0
# 4       01/01/2018   0.0             Theft            1.0
# ...            ...   ...               ...            ...
# 406479      9/9/19  23.0  Burglary/Robbery            1.0
# 406480      9/9/19  23.0             Theft            1.0
# 406481      9/9/19  23.0  Burglary/Robbery            1.0
# 406482      9/9/19  23.0           Assault            1.0
# 406483      9/9/19  23.0             Theft            1.0
#
#                                          Premise Block_Range  \
# 0                             Residence or House        1300
# 1                                      Apartment        3900
# 2                      Road, Street, or Sidewalk        7200
# 3                      Road, Street, or Sidewalk        4900
# 4       Church, Synagogue, or Temple Parking Lot        3100
# ...                                          ...         ...
# 406479      Residence, Home (Includes Apartment)        2555
# 406480      Residence, Home (Includes Apartment)        2555
# 406481               Commercial, Office Building        8499
# 406482                       Parking Lot, Garage        2434
# 406483                       Parking Lot, Garage        8215
#
#                 Street_Name Street_Type     City State  \
# 0                  ROSEDALE          ST  Houston    TX
# 1       ARLINGTON SQUARE DR           -  Houston    TX
# 2           BELLERIVE DRIVE           -  Houston    TX
# 3                  DANFIELD           -  Houston    TX
# 4                  CLEBURNE          ST  Houston    TX
# ...                     ...         ...      ...   ...
# 406479               BERING          DR  Houston    TX
# 406480               BERING          DR  Houston    TX
# 406481                 GULF         FWY  Houston    TX
# 406482             LIDSTONE         NaN  Houston    TX
# 406483               KOPMAN          DR  Houston    TX
#
#                     Street_Address                             Full_Address  \
# 0                 1300+ROSEDALE+ST            1300 ROSEDALE ST, Houston, TX
# 1       3900+ARLINGTON+SQUARE+DR+-  3900 ARLINGTON SQUARE DR -, Houston, TX
# 2           7200+BELLERIVE+DRIVE+-      7200 BELLERIVE DRIVE -, Houston, TX
# 3                  4900+DANFIELD+-             4900 DANFIELD -, Houston, TX
# 4                 3100+CLEBURNE+ST            3100 CLEBURNE ST, Houston, TX
# ...                            ...                                      ...
# 406479              2555+BERING+DR              2555 BERING DR, Houston, TX
# 406480              2555+BERING+DR              2555 BERING DR, Houston, TX
# 406481               8499+GULF+FWY               8499 GULF FWY, Houston, TX
# 406482              2434+LIDSTONE+              2434 LIDSTONE , Houston, TX
# 406483              8215+KOPMAN+DR              8215 KOPMAN DR, Houston, TX
#
#          Latitude  Longitude   Tract  Year  Month  Day
# 0       29.728702 -95.383298  313100  2018      1    1
# 1       29.647820 -95.219253  321300  2018      1    1
# 2       29.713171 -95.511054  432801  2018      1    1
# 3       29.600076 -95.452984  330700  2018      1    1
# 4       29.724583 -95.362610  312800  2018      1    1
# ...           ...        ...     ...   ...    ...  ...
# 406479  29.739422 -95.479333  431402  2019      9    9
# 406480  29.739422 -95.479333  431402  2019      9    9
# 406481  29.670256 -95.263593  320602  2019      9    9
# 406482  29.715633 -95.321752  311900  2019      9    9
# 406483  29.643764 -95.304823     nan  2019      9    9
#
# [406484 rows x 18 columns]

# %%
crime_data.dtypes
# Out:
# Date               object
# Hour              float64
# Offense_Type       object
# Offense_Count     float64
# Premise            object
# Block_Range        object
# Street_Name        object
# Street_Type        object
# City               object
# State              object
# Street_Address     object
# Full_Address       object
# Latitude          float64
# Longitude         float64
# Tract              object
# Year                int64
# Month               int64
# Day                 int64
# dtype: object

# %%
crime_data['Hour'] = crime_data['Hour'].astype(int)

# %%
crime_data.dtypes
# Out:
# Date               object
# Hour                int32
# Offense_Type       object
# Offense_Count     float64
# Premise            object
# Block_Range        object
# Street_Name        object
# Street_Type        object
# City               object
# State              object
# Street_Address     object
# Full_Address       object
# Latitude          float64
# Longitude         float64
# Tract              object
# Year                int64
# Month               int64
# Day                 int64
# dtype: object

# %%
houston_weather.dtypes
# Out:
# Unnamed: 0               int64
# Date_Time               object
# Date                    object
# Year                     int64
# Month                    int64
# Week_Num                 int64
# Day                      int64
# Hour                     int64
# Day_of_Week             object
# Temperature            float64
# Precipitation          float64
# Weather                 object
# Weather_Description     object
# dtype: object

# %%
full_data = pd.merge(crime_data, houston_weather, on = ['Year', 'Month', 'Day', 'Hour'], how="left")

# %%
del full_data["Date_Time"]
del full_data["Date_y"]
del full_data["Unnamed: 0"]

# %%
full_data = full_data.rename(columns = {"Date_x":"Date"})

# %%
full_data
# Out:
#               Date  Hour      Offense_Type  Offense_Count  \
# 0       01/01/2018     0  Burglary/Robbery            1.0
# 1       01/01/2018     0  Burglary/Robbery            1.0
# 2       01/01/2018     0  Burglary/Robbery            1.0
# 3       01/01/2018     0           Assault            2.0
# 4       01/01/2018     0             Theft            1.0
# ...            ...   ...               ...            ...
# 423896      9/9/19    23  Burglary/Robbery            1.0
# 423897      9/9/19    23             Theft            1.0
# 423898      9/9/19    23  Burglary/Robbery            1.0
# 423899      9/9/19    23           Assault            1.0
# 423900      9/9/19    23             Theft            1.0
#
#                                          Premise Block_Range  \
# 0                             Residence or House        1300
# 1                                      Apartment        3900
# 2                      Road, Street, or Sidewalk        7200
# 3                      Road, Street, or Sidewalk        4900
# 4       Church, Synagogue, or Temple Parking Lot        3100
# ...                                          ...         ...
# 423896      Residence, Home (Includes Apartment)        2555
# 423897      Residence, Home (Includes Apartment)        2555
# 423898               Commercial, Office Building        8499
# 423899                       Parking Lot, Garage        2434
# 423900                       Parking Lot, Garage        8215
#
#                 Street_Name Street_Type     City State  ...   Tract  Year  \
# 0                  ROSEDALE          ST  Houston    TX  ...  313100  2018
# 1       ARLINGTON SQUARE DR           -  Houston    TX  ...  321300  2018
# 2           BELLERIVE DRIVE           -  Houston    TX  ...  432801  2018
# 3                  DANFIELD           -  Houston    TX  ...  330700  2018
# 4                  CLEBURNE          ST  Houston    TX  ...  312800  2018
# ...                     ...         ...      ...   ...  ...     ...   ...
# 423896               BERING          DR  Houston    TX  ...  431402  2019
# 423897               BERING          DR  Houston    TX  ...  431402  2019
# 423898                 GULF         FWY  Houston    TX  ...  320602  2019
# 423899             LIDSTONE         NaN  Houston    TX  ...  311900  2019
# 423900               KOPMAN          DR  Houston    TX  ...     nan  2019
#
#         Month  Day Week_Num  Day_of_Week  Temperature  Precipitation  Weather  \
# 0           1    1      1.0       Monday        46.56            0.0   Clouds
# 1           1    1      1.0       Monday        46.56            0.0   Clouds
# 2           1    1      1.0       Monday        46.56            0.0   Clouds
# 3           1    1      1.0       Monday        46.56            0.0   Clouds
# 4           1    1      1.0       Monday        46.56            0.0   Clouds
# ...       ...  ...      ...          ...          ...            ...      ...
# 423896      9    9     37.0       Monday        90.34            0.0    Clear
# 423897      9    9     37.0       Monday        90.34            0.0    Clear
# 423898      9    9     37.0       Monday        90.34            0.0    Clear
# 423899      9    9     37.0       Monday        90.34            0.0    Clear
# 423900      9    9     37.0       Monday        90.34            0.0    Clear
#
#        Weather_Description
# 0          overcast clouds
# 1          overcast clouds
# 2          overcast clouds
# 3          overcast clouds
# 4          overcast clouds
# ...                    ...
# 423896        sky is clear
# 423897        sky is clear
# 423898        sky is clear
# 423899        sky is clear
# 423900        sky is clear
#
# [423901 rows x 24 columns]

# %% [markdown]
# ## Adding census data

# %%
#adding required libraries
import requests
from config import census_api_key

# %%
#Dataset:
#https://api.census.gov/data.html
#American Community Survey (ACS) 5-Year Data Profiles year 2018 

base_url="https://api.census.gov/data"
year="2018"

#api.census.gov/data.html
dataset_name="acs/acs5/subject"

#Selected the variables:
#S0101_C01_001E - Estimate!!Total!!Total population
#S1101_C01_001E - Estimate!!Total!!HOUSEHOLDS!!Total households
#S1901_C01_012E - Estimate!!Households!!Median income (dollars)

variable="S0101_C01_001E,S1101_C01_001E,S1901_C01_012E"
geography="for=tract:*&in=state:48"

# %%
#define URL for querying census data
url=f"{base_url}/{year}/{dataset_name}?get={variable}&{geography}&key={census_api_key}"
#get response from census and store it
response = requests.get(url)
response.json()
# Out:
# [['S0101_C01_001E',
#   'S1101_C01_001E',
#   'S1901_C01_012E',
#   'state',
#   'county',
#   'tract'],
#  ['1302', '686', '14569', '48', '027', '020701'],
#  ['4354', '1599', '46481', '48', '027', '021202'],
#  ['9873', '3538', '69833', '48', '027', '021303'],
#  ['3825', '1304', '54441', '48', '027', '021901'],
#  ['4308', '1745', '28423', '48', '027', '022600'],
#  ['5117', '1527', '74561', '48', '029', '141402'],
#  ['3102', '1655', '44050', '48', '029', '110100'],
#  ['1430', '432', '75833', '48', '173', '950100'],
#  ['5699', '1621', '44792', '48', '185', '180101'],
#  ['4192', '1722', '39825', '48', '185', '180102'],
#  ['7168', '2289', '54353', '48', '185', '180200'],
#  ['4980', '1890', '59611', '48', '185', '180301'],
#  ['3288', '1217', '40536', '48', '185', '180302'],
#  ['4465', '1462', '46162', '48', '453', '002110'],
#  ['3038', '1484', '36446', '48', '453', '002315'],
#  ['5590', '1708', '44331', '48', '113', '017400'],
#  ['7832', '2464', '48328', '48', '113', '017804'],
#  ['6896', '2441', '48147', '48', '113', '017813'],
#  ['5025', '1498', '55227', '48', '113', '018401'],
#  ['2978', '1187', '42188', '48', '113', '019016'],
#  ['6048', '2223', '72813', '48', '113', '019031'],
#  ['3869', '1112', '53382', '48', '113', '019032'],
#  ['7283', '3286', '44931', '48', '029', '120902'],
#  ['5679', '1994', '40462', '48', '029', '121403'],
#  ['8661', '2843', '66875', '48', '029', '121604'],
#  ['4045', '1355', '21554', '48', '029', '130600'],
#  ['2951', '907', '31726', '48', '029', '140200'],
#  ['5833', '1951', '78917', '48', '029', '181718'],
#  ['4020', '1440', '77908', '48', '029', '181811'],
#  ['4302', '1866', '55543', '48', '029', '190200'],
#  ['3601', '983', '47596', '48', '029', '190501'],
#  ['1999', '748', '167667', '48', '029', '190800'],
#  ['6122', '2131', '40762', '48', '029', '190901'],
#  ['6782', '2025', '41513', '48', '029', '150900'],
#  ['5492', '1627', '37629', '48', '029', '140800'],
#  ['3425', '1008', '36667', '48', '029', '150502'],
#  ['7060', '1980', '38594', '48', '029', '150700'],
#  ['7188', '1965', '24980', '48', '029', '160100'],
#  ['4887', '1575', '31568', '48', '029', '170500'],
#  ['4704', '1239', '38345', '48', '029', '180504'],
#  ['5553', '1691', '34821', '48', '029', '120502'],
#  ['5907', '2252', '41362', '48', '029', '120701'],
#  ['7290', '2561', '60194', '48', '029', '121504'],
#  ['5206', '1306', '42594', '48', '029', '150300'],
#  ['2995', '905', '33281', '48', '029', '160200'],
#  ['7830', '2553', '60513', '48', '029', '181713'],
#  ['4932', '1661', '69926', '48', '029', '181505'],
#  ['6397', '1857', '57482', '48', '029', '181704'],
#  ['4755', '1415', '24594', '48', '061', '013106'],
#  ['4665', '1320', '34556', '48', '061', '013305'],
#  ['2894', '679', '33185', '48', '061', '013309'],
#  ['1864', '577', '20179', '48', '061', '013402'],
#  ['1974', '671', '42946', '48', '061', '013500'],
#  ['4914', '1648', '65435', '48', '061', '012613'],
#  ['2576', '660', '25082', '48', '061', '013306'],
#  ['2401', '679', '39618', '48', '061', '010201'],
#  ['7427', '2375', '32020', '48', '061', '010800'],
#  ['2512', '644', '26458', '48', '061', '010500'],
#  ['8131', '2786', '32371', '48', '061', '010601'],
#  ['1456', '488', '21944', '48', '061', '010900'],
#  ['17713', '4833', '52127', '48', '061', '012504'],
#  ['3463', '882', '22065', '48', '061', '013206'],
#  ['3603', '812', '28715', '48', '061', '013308'],
#  ['2439', '655', '16652', '48', '061', '013801'],
#  ['4200', '1090', '25043', '48', '061', '013903'],
#  ['1546', '559', '64250', '48', '061', '010602'],
#  ['1688', '516', '26316', '48', '061', '011200'],
#  ['6774', '2116', '43750', '48', '061', '011400'],
#  ['5023', '1673', '40644', '48', '061', '011902'],
#  ['2548', '683', '32989', '48', '061', '011903'],
#  ['4269', '1559', '29464', '48', '061', '013002'],
#  ['4270', '1086', '19948', '48', '061', '013700'],
#  ['2778', '943', '37670', '48', '061', '013004'],
#  ['3805', '1105', '39540', '48', '061', '013303'],
#  ['2595', '705', '20096', '48', '061', '013401'],
#  ['3016', '914', '32708', '48', '061', '013600'],
#  ['3109', '856', '18615', '48', '061', '013802'],
#  ['2641', '695', '25486', '48', '061', '013901'],
#  ['9345', '3031', '37153', '48', '061', '010100'],
#  ['6075', '1963', '35136', '48', '061', '011801'],
#  ['8971', '2712', '81310', '48', '029', '181711'],
#  ['3036', '1351', '46042', '48', '029', '190700'],
#  ['3999', '1440', '67159', '48', '029', '190902'],
#  ['3698', '1415', '51450', '48', '029', '181001'],
#  ['5308', '2611', '42255', '48', '029', '181004'],
#  ['3004', '935', '120202', '48', '029', '182103'],
#  ['3801', '1339', '36648', '48', '029', '190100'],
#  ['14664', '5100', '42377', '48', '029', '171902'],
#  ['4761', '1484', '35181', '48', '029', '180400'],
#  ['4028', '1942', '46750', '48', '029', '180701'],
#  ['6240', '2382', '65807', '48', '029', '181100'],
#  ['8893', '3449', '69979', '48', '029', '191405'],
#  ['4021', '1259', '26044', '48', '029', '170900'],
#  ['5033', '1361', '60422', '48', '029', '180503'],
#  ['3721', '1350', '37078', '48', '029', '180602'],
#  ['2611', '989', '91771', '48', '029', '191102'],
#  ['4159', '1161', '27472', '48', '029', '161000'],
#  ['1114', '562', '14891', '48', '029', '110700'],
#  ['3969', '1463', '36756', '48', '223', '950600'],
#  ['5070', '1672', '49659', '48', '223', '950700'],
#  ['3013', '1117', '58542', '48', '223', '950100'],
#  ['4264', '1619', '57610', '48', '223', '950200'],
#  ['2931', '1129', '65544', '48', '223', '950800'],
#  ['5909', '2167', '68606', '48', '223', '950300'],
#  ['2852', '979', '48096', '48', '223', '950500'],
#  ['1508', '530', '78977', '48', '357', '950100'],
#  ['3756', '1162', '49722', '48', '357', '950300'],
#  ['5084', '1751', '46830', '48', '357', '950400'],
#  ['228', '91', '65125', '48', '269', '950100'],
#  ['1834', '629', '46648', '48', '275', '950100'],
#  ['1899', '701', '43250', '48', '275', '950200'],
#  ['4972', '2086', '53326', '48', '309', '002501'],
#  ['3766', '1322', '96346', '48', '309', '002504'],
#  ['3027', '942', '26458', '48', '309', '000800'],
#  ['7229', '2988', '23668', '48', '309', '001400'],
#  ['2626', '995', '52254', '48', '309', '003602'],
#  ['8306', '3677', '56754', '48', '309', '003707'],
#  ['3751', '1604', '30726', '48', '115', '950500'],
#  ['1500', '564', '63816', '48', '115', '950600'],
#  ['3596', '1321', '101908', '48', '113', '019037'],
#  ['4235', '1479', '122321', '48', '113', '019210'],
#  ['3241', '904', '40227', '48', '113', '013717'],
#  ['4870', '2670', '74510', '48', '113', '014121'],
#  ['4209', '2008', '26907', '48', '113', '012210'],
#  ['7599', '2883', '41115', '48', '113', '011001'],
#  ['5270', '1830', '54848', '48', '113', '012206'],
#  ['8200', '2486', '43773', '48', '113', '012500'],
#  ['3835', '1311', '81028', '48', '113', '013007'],
#  ['6117', '2141', '104441', '48', '113', '013605'],
#  ['3422', '958', '47663', '48', '113', '013711'],
#  ['2220', '689', '57750', '48', '113', '013712'],
#  ['4437', '1926', '44611', '48', '113', '014403'],
#  ['3589', '1017', '35208', '48', '113', '015202'],
#  ['2039', '527', '48589', '48', '113', '015303'],
#  ['3345', '1137', '52305', '48', '113', '015403'],
#  ['5543', '1893', '53915', '48', '113', '000401'],
#  ['5708', '3891', '69679', '48', '113', '000500'],
#  ['5057', '2579', '56831', '48', '113', '000900'],
#  ['2187', '1144', '45069', '48', '113', '001302'],
#  ['3785', '1749', '50708', '48', '113', '001400'],
#  ['3437', '1579', '104148', '48', '113', '004400'],
#  ['1893', '928', '59758', '48', '113', '004600'],
#  ['6118', '2142', '51639', '48', '113', '019029'],
#  ['2940', '1046', '29292', '48', '113', '008801'],
#  ['6687', '1699', '37404', '48', '113', '009202'],
#  ['4490', '2126', '60266', '48', '113', '009604'],
#  ['3530', '1285', '111250', '48', '113', '009607'],
#  ['3353', '1315', '99531', '48', '113', '009608'],
#  ['4363', '1491', '36625', '48', '113', '006100'],
#  ['2199', '1188', '32344', '48', '113', '007819'],
#  ['2148', '1010', '97984', '48', '113', '007903'],
#  ['4715', '1948', '24294', '48', '113', '008802'],
#  ['3343', '1293', '29625', '48', '113', '008900'],
#  ['3733', '1082', '37937', '48', '113', '009105'],
#  ['6556', '1883', '33125', '48', '113', '009201'],
#  ['4201', '1092', '42973', '48', '113', '009303'],
#  ['10437', '2363', '65787', '48', '113', '010000'],
#  ['5057', '1380', '35714', '48', '113', '010101'],
#  ['7350', '2544', '55473', '48', '113', '010803'],
#  ['3692', '1257', '49539', '48', '113', '011002'],
#  ['4555', '1573', '51307', '48', '113', '011101'],
#  ['4868', '1642', '30767', '48', '113', '011105'],
#  ['4807', '1439', '29857', '48', '113', '011601'],
#  ['2704', '1110', '23205', '48', '113', '012208'],
#  ['4555', '1821', '32850', '48', '113', '012211'],
#  ['5363', '2109', '60976', '48', '113', '012400'],
#  ['4622', '2385', '90092', '48', '113', '012900'],
#  ['5182', '1812', '62093', '48', '113', '013009'],
#  ['6814', '3649', '97163', '48', '113', '013200'],
#  ['5842', '2475', '69338', '48', '113', '013606'],
#  ['2571', '1046', '139417', '48', '113', '013608'],
#  ['7223', '4070', '72828', '48', '113', '013616'],
#  ['5155', '2103', '134456', '48', '113', '013619'],
#  ['7007', '1977', '55493', '48', '113', '013714'],
#  ['5171', '1642', '65703', '48', '113', '013902'],
#  ['1841', '735', '56902', '48', '337', '950200'],
#  ['4921', '2003', '63807', '48', '337', '950400'],
#  ['5425', '2215', '49114', '48', '337', '950500'],
#  ['1989', '837', '54922', '48', '337', '950600'],
#  ['2813', '1123', '35625', '48', '337', '950300'],
#  ['1957', '760', '40051', '48', '351', '950100'],
#  ['5518', '1919', '44583', '48', '351', '950200'],
#  ['3273', '1037', '40618', '48', '351', '950300'],
#  ['3309', '1262', '39875', '48', '351', '950400'],
#  ['4475', '1758', '51176', '48', '365', '950100'],
#  ['4088', '1580', '48750', '48', '365', '950300'],
#  ['2544', '1028', '61029', '48', '365', '950500'],
#  ['6511', '2420', '51220', '48', '365', '950400'],
#  ['3331', '1205', '59803', '48', '365', '950200'],
#  ['2491', '836', '50333', '48', '365', '950600'],
#  ['3059', '851', '31771', '48', '389', '950200'],
#  ['1946', '560', '66742', '48', '389', '950300'],
#  ['4309', '532', '49598', '48', '389', '950100'],
#  ['4675', '1357', '73943', '48', '389', '950400'],
#  ['1136', '413', '41550', '48', '389', '950500'],
#  ['3295', '1221', '34011', '48', '403', '950200'],
#  ['2466', '890', '36889', '48', '403', '950100'],
#  ['4697', '1988', '29948', '48', '403', '950300'],
#  ['3058', '1055', '56576', '48', '421', '950200'],
#  ['4281', '1534', '33315', '48', '437', '950300'],
#  ['1313', '457', '45375', '48', '437', '950400'],
#  ['1890', '523', '42014', '48', '437', '950200'],
#  ['2756', '867', '58288', '48', '231', '960200'],
#  ['4908', '1571', '38556', '48', '231', '961000'],
#  ['6831', '2439', '74188', '48', '231', '961100'],
#  ['9742', '3129', '78969', '48', '231', '961400'],
#  ['2832', '1061', '44620', '48', '231', '961700'],
#  ['4028', '1455', '62750', '48', '231', '960300'],
#  ['3625', '1393', '69191', '48', '453', '002409'],
#  ['4524', '1776', '51853', '48', '453', '002410'],
#  ['4833', '2000', '39467', '48', '453', '002419'],
#  ['10705', '4375', '65376', '48', '453', '002421'],
#  ['2812', '1069', '93554', '48', '453', '000803'],
#  ['5513', '3314', '81709', '48', '453', '001200'],
#  ['4259', '1124', '64545', '48', '029', '190400'],
#  ['7940', '3363', '61725', '48', '029', '121108'],
#  ['3025', '1037', '16012', '48', '029', '150800'],
#  ['4089', '1148', '28472', '48', '029', '171200'],
#  ['4196', '1238', '42202', '48', '029', '141800'],
#  ['7600', '2306', '80975', '48', '029', '171912'],
#  ['4404', '1327', '82193', '48', '029', '181712'],
#  ['5924', '1881', '39858', '48', '029', '181602'],
#  ['5619', '1773', '61128', '48', '029', '121505'],
#  ['3588', '1042', '27273', '48', '029', '140300'],
#  ['2993', '749', '44583', '48', '029', '152000'],
#  ['3712', '1046', '26538', '48', '029', '170101'],
#  ['6128', '1965', '30099', '48', '029', '171802'],
#  ['7092', '2111', '46485', '48', '017', '950100'],
#  ['19137', '6063', '106288', '48', '071', '710200'],
#  ['0', '0', '-666666666', '48', '071', '710600'],
#  ['8726', '3050', '76944', '48', '071', '710100'],
#  ['2985', '974', '61063', '48', '071', '710300'],
#  ['3718', '1312', '39672', '48', '071', '710500'],
#  ['3645', '1314', '45995', '48', '027', '020500'],
#  ['4656', '1904', '50714', '48', '027', '021203'],
#  ['5244', '2066', '63000', '48', '027', '021301'],
#  ['6839', '2144', '48571', '48', '027', '021500'],
#  ['8255', '2664', '37846', '48', '029', '161501'],
#  ['2310', '568', '48333', '48', '029', '162001'],
#  ['3619', '1172', '31063', '48', '029', '170102'],
#  ['3835', '1099', '27660', '48', '029', '171100'],
#  ['6786', '2963', '35023', '48', '029', '180702'],
#  ['5687', '1899', '48352', '48', '029', '180901'],
#  ['4175', '1277', '30150', '48', '029', '181303'],
#  ['6337', '3149', '42957', '48', '029', '181504'],
#  ['3340', '1107', '49375', '48', '029', '181601'],
#  ['6490', '2341', '47971', '48', '029', '181809'],
#  ['8950', '3144', '120441', '48', '029', '182101'],
#  ['4183', '1171', '40711', '48', '029', '190601'],
#  ['4531', '1361', '35549', '48', '029', '191004'],
#  ['6557', '3058', '48590', '48', '029', '181302'],
#  ['7738', '2531', '36098', '48', '029', '180902'],
#  ['6201', '2125', '46125', '48', '055', '960700'],
#  ['2536', '942', '45769', '48', '487', '950700'],
#  ['1767', '673', '70380', '48', '487', '950300'],
#  ['2532', '1042', '26568', '48', '487', '950500'],
#  ['6071', '2606', '56078', '48', '487', '950600'],
#  ['1701', '524', '59583', '48', '317', '950100'],
#  ['3913', '1102', '72955', '48', '317', '950200'],
#  ['3752', '1147', '70478', '48', '383', '950100'],
#  ['6708', '2008', '69625', '48', '501', '950200'],
#  ['1863', '668', '63654', '48', '501', '950100'],
#  ['6392', '2463', '50808', '48', '189', '950300'],
#  ['2951', '993', '49242', '48', '189', '950900'],
#  ['3313', '1073', '45515', '48', '189', '950500'],
#  ['2790', '999', '42168', '48', '189', '950700'],
#  ['1235', '467', '44135', '48', '189', '950800'],
#  ['4438', '1430', '33583', '48', '189', '950100'],
#  ['4413', '1088', '51667', '48', '189', '950600'],
#  ['3745', '1149', '36411', '48', '189', '950200'],
#  ['1930', '897', '39205', '48', '151', '950400'],
#  ['1953', '752', '52396', '48', '151', '950300'],
#  ['4836', '1313', '30344', '48', '131', '950100'],
#  ['2913', '915', '45149', '48', '131', '950200'],
#  ['1358', '586', '63958', '48', '051', '970100'],
#  ['4432', '1660', '63611', '48', '051', '970200'],
#  ['4570', '1708', '52297', '48', '051', '970500'],
#  ['3053', '1175', '73542', '48', '051', '970400'],
#  ['4450', '1625', '44911', '48', '051', '970300'],
#  ['5845', '2125', '52614', '48', '031', '950200'],
#  ['5434', '2172', '68571', '48', '031', '950100'],
#  ['3451', '1051', '34968', '48', '241', '950300'],
#  ['8136', '2772', '62133', '48', '241', '950700'],
#  ['4333', '1669', '56864', '48', '241', '950500'],
#  ['5844', '1870', '47565', '48', '241', '950400'],
#  ['5159', '2069', '48983', '48', '241', '950100'],
#  ['3282', '1171', '35813', '48', '241', '950200'],
#  ['2800', '1051', '24347', '48', '241', '950600'],
#  ['2499', '930', '48750', '48', '241', '950800'],
#  ['3522', '1325', '35388', '48', '245', '002500'],
#  ['2015', '665', '51146', '48', '245', '010200'],
#  ['2705', '1086', '48088', '48', '245', '010400'],
#  ['3313', '1482', '63611', '48', '245', '011002'],
#  ['5932', '2059', '38004', '48', '245', '001301'],
#  ['2220', '800', '49548', '48', '245', '000102'],
#  ['1440', '545', '28583', '48', '245', '005900'],
#  ['5008', '1977', '54458', '48', '245', '010800'],
#  ['5130', '1917', '77266', '48', '201', '551400'],
#  ['11478', '3556', '58893', '48', '201', '552500'],
#  ['2657', '745', '40121', '48', '201', '210700'],
#  ['1941', '689', '34261', '48', '201', '211000'],
#  ['5478', '1409', '35275', '48', '201', '211900'],
#  ['3606', '1761', '17616', '48', '201', '220500'],
#  ['9920', '2481', '43191', '48', '201', '221300'],
#  ['5977', '1801', '35568', '48', '201', '221400'],
#  ['8350', '2602', '28984', '48', '201', '221500'],
#  ['4000', '1065', '31899', '48', '201', '221800'],
#  ['4790', '1252', '42813', '48', '201', '221900'],
#  ['5109', '1981', '26467', '48', '201', '222600'],
#  ['5773', '2131', '20131', '48', '201', '222700'],
#  ['2873', '995', '26383', '48', '201', '230700'],
#  ['4227', '1621', '22198', '48', '201', '230900'],
#  ['6998', '2191', '35998', '48', '201', '231200'],
#  ['8901', '2968', '61179', '48', '201', '241000'],
#  ['8103', '2992', '54693', '48', '201', '252900'],
#  ['4218', '1670', '53971', '48', '201', '253900'],
#  ['3967', '1474', '47125', '48', '201', '254000'],
#  ['5221', '1812', '44899', '48', '201', '254300'],
#  ['5874', '2050', '34587', '48', '201', '310600'],
#  ['5287', '587', '74219', '48', '201', '312000'],
#  ['5953', '1937', '28475', '48', '201', '211100'],
#  ['2862', '850', '40357', '48', '201', '313500'],
#  ['2265', '903', '43679', '48', '201', '313700'],
#  ['10445', '3584', '63500', '48', '491', '020504'],
#  ['3095', '934', '40833', '48', '491', '021000'],
#  ['3691', '1305', '82266', '48', '491', '020404'],
#  ['6481', '2636', '52056', '48', '491', '020405'],
#  ['3033', '899', '51563', '48', '491', '021100'],
#  ['3719', '1391', '56317', '48', '491', '021202'],
#  ['3080', '1141', '45804', '48', '491', '021203'],
#  ['11524', '3230', '81111', '48', '491', '021401'],
#  ['6017', '1952', '74157', '48', '491', '021403'],
#  ['5778', '1649', '54191', '48', '491', '021502'],
#  ['3703', '1162', '127000', '48', '491', '020310'],
#  ['6067', '2122', '57716', '48', '491', '020704'],
#  ['4279', '1364', '72193', '48', '491', '020900'],
#  ['6081', '2278', '69783', '48', '181', '000800'],
#  ['4320', '1658', '55147', '48', '181', '000901'],
#  ['7235', '2339', '42586', '48', '181', '001500'],
#  ['6041', '2250', '60000', '48', '181', '001801'],
#  ['3738', '1489', '38931', '48', '181', '000700'],
#  ['4639', '1811', '63673', '48', '181', '001101'],
#  ['4029', '1658', '41250', '48', '181', '001300'],
#  ['5281', '2138', '41948', '48', '181', '001700'],
#  ['2568', '1151', '28301', '48', '027', '022801'],
#  ['3263', '1328', '38542', '48', '027', '023104'],
#  ['2045', '620', '28000', '48', '027', '020702'],
#  ['4330', '1682', '31831', '48', '027', '021000'],
#  ['3974', '1401', '62654', '48', '027', '021400'],
#  ['7057', '2303', '61226', '48', '027', '020100'],
#  ['2689', '993', '51069', '48', '027', '020600'],
#  ['5301', '1992', '47566', '48', '027', '021100'],
#  ['3236', '1638', '50943', '48', '027', '021201'],
#  ['6099', '2148', '48716', '48', '027', '022401'],
#  ['7835', '2193', '97210', '48', '027', '022402'],
#  ['3186', '1369', '69475', '48', '027', '021302'],
#  ['3256', '443', '49432', '48', '027', '021602'],
#  ['10159', '3215', '75716', '48', '027', '020300'],
#  ['2957', '1004', '32404', '48', '027', '020800'],
#  ['2756', '924', '22129', '48', '027', '020900'],
#  ['8395', '3776', '58258', '48', '027', '021700'],
#  ['9045', '3271', '58454', '48', '027', '021800'],
#  ['3884', '1706', '31585', '48', '027', '022900'],
#  ['4798', '1872', '38938', '48', '027', '023103'],
#  ['8006', '2871', '45549', '48', '027', '022000'],
#  ['9723', '3202', '78280', '48', '027', '023300'],
#  ['1948', '853', '24283', '48', '027', '023500'],
#  ['7422', '2134', '31385', '48', '201', '323000'],
#  ['3807', '1159', '34176', '48', '201', '323300'],
#  ['4208', '1187', '32823', '48', '201', '331800'],
#  ['3424', '920', '36781', '48', '201', '332100'],
#  ['3425', '1001', '59321', '48', '201', '333000'],
#  ['3395', '958', '47803', '48', '201', '333700'],
#  ['6705', '2514', '80528', '48', '201', '521900'],
#  ['5468', '1862', '32354', '48', '201', '533600'],
#  ['3039', '1353', '73631', '48', '201', '542500'],
#  ['2061', '777', '79792', '48', '201', '341800'],
#  ['6677', '2558', '48391', '48', '201', '340100'],
#  ['6861', '2863', '47250', '48', '201', '340500'],
#  ['5641', '2161', '77163', '48', '201', '342500'],
#  ['4863', '1718', '65640', '48', '201', '342700'],
#  ['7070', '2552', '65084', '48', '201', '343000'],
#  ['3872', '1554', '164722', '48', '201', '411100'],
#  ['3941', '1261', '250001', '48', '201', '412600'],
#  ['3794', '1653', '106094', '48', '201', '420300'],
#  ['7875', '2858', '29468', '48', '201', '421500'],
#  ['3014', '1247', '59188', '48', '201', '531500'],
#  ['3425', '1273', '131932', '48', '201', '531700'],
#  ['1894', '911', '33854', '48', '201', '312300'],
#  ['2514', '663', '12260', '48', '201', '312800'],
#  ['4022', '1630', '39816', '48', '201', '312900'],
#  ['8691', '2753', '72936', '48', '201', '350200'],
#  ['5036', '2118', '51368', '48', '201', '340900'],
#  ['4212', '1419', '74283', '48', '201', '342100'],
#  ['7912', '2347', '49480', '48', '201', '350500'],
#  ['4630', '2536', '102778', '48', '201', '410500'],
#  ['3208', '1832', '67700', '48', '201', '411700'],
#  ['5633', '2331', '120436', '48', '201', '430800'],
#  ['4596', '1998', '188571', '48', '201', '431700'],
#  ['5501', '2435', '28813', '48', '201', '432500'],
#  ['5244', '1846', '138500', '48', '201', '450200'],
#  ['5792', '2003', '58089', '48', '201', '451800'],
#  ['8907', '2606', '37337', '48', '201', '452600'],
#  ['5807', '2107', '63328', '48', '309', '003802'],
#  ['4722', '1727', '45879', '48', '309', '003200'],
#  ['4046', '1901', '53510', '48', '453', '001503'],
#  ['3420', '1638', '80849', '48', '453', '001602'],
#  ['4803', '2011', '60433', '48', '453', '001712'],
#  ['4588', '2000', '80776', '48', '453', '001746'],
#  ['6998', '3019', '88083', '48', '453', '001749'],
#  ['2169', '966', '116500', '48', '453', '001751'],
#  ['7423', '2385', '39241', '48', '453', '001813'],
#  ['2373', '1429', '48259', '48', '453', '001829'],
#  ['12791', '3533', '56175', '48', '453', '001842'],
#  ['3922', '1598', '58550', '48', '453', '001844'],
#  ['4191', '1564', '182981', '48', '453', '001912'],
#  ['4929', '2103', '40901', '48', '453', '002105'],
#  ['4314', '1653', '49583', '48', '453', '002109'],
#  ['6613', '2654', '43289', '48', '453', '002308'],
#  ['4560', '2065', '42744', '48', '453', '002313'],
#  ['6816', '3115', '111379', '48', '453', '001716'],
#  ['5001', '2358', '65000', '48', '453', '001754'],
#  ['6034', '2325', '111507', '48', '453', '001769'],
#  ['4017', '2244', '57661', '48', '453', '001817'],
#  ['2623', '1251', '62117', '48', '453', '001826'],
#  ['5373', '2147', '71023', '48', '453', '001848'],
#  ['4699', '1797', '126518', '48', '453', '001910'],
#  ['3170', '1757', '71335', '48', '453', '001911'],
#  ['5628', '2584', '70847', '48', '453', '002005'],
#  ['9223', '2529', '40732', '48', '453', '002202'],
#  ['5775', '1923', '34813', '48', '061', '011901'],
#  ['10169', '2371', '48407', '48', '061', '012505'],
#  ['6236', '1741', '66202', '48', '061', '012612'],
#  ['3526', '1360', '38333', '48', '061', '013104'],
#  ['7643', '2527', '48750', '48', '061', '010402'],
#  ['5640', '1540', '51221', '48', '061', '012402'],
#  ['5118', '1269', '29424', '48', '061', '013207'],
#  ['6027', '1821', '22798', '48', '061', '011600'],
#  ['2468', '638', '18650', '48', '061', '014002'],
#  ['10993', '3098', '31734', '48', '061', '012200'],
#  ['4518', '1564', '34022', '48', '061', '012900'],
#  ['1534', '519', '48398', '48', '061', '011301'],
#  ['7037', '1749', '30397', '48', '061', '012609'],
#  ['14079', '4647', '124675', '48', '121', '020303'],
#  ['3648', '1526', '48039', '48', '121', '020403'],
#  ['10099', '3393', '58351', '48', '121', '020602'],
#  ['2746', '1450', '30345', '48', '121', '020700'],
#  ['4418', '1704', '35000', '48', '121', '021301'],
#  ['4551', '1702', '77963', '48', '121', '021611'],
#  ['4433', '2007', '47724', '48', '121', '021616'],
#  ['4967', '1508', '75174', '48', '121', '021615'],
#  ['4649', '1589', '51848', '48', '121', '021502'],
#  ['11958', '4285', '80747', '48', '121', '021403'],
#  ['2095', '779', '30272', '48', '201', '233600'],
#  ['8110', '2403', '52276', '48', '201', '240400'],
#  ['4157', '1537', '42403', '48', '201', '252700'],
#  ['6917', '2239', '52930', '48', '201', '252800'],
#  ['11333', '3147', '110276', '48', '201', '253100'],
#  ['5327', '2540', '66221', '48', '201', '310100'],
#  ['2711', '1164', '224500', '48', '201', '411400'],
#  ['3925', '1217', '31076', '48', '201', '420500'],
#  ['4190', '1255', '38640', '48', '201', '220400'],
#  ['5220', '1410', '36346', '48', '201', '332900'],
#  ['2874', '1669', '111299', '48', '201', '410300'],
#  ['3398', '1190', '250001', '48', '201', '430400'],
#  ['4785', '1772', '32083', '48', '201', '433400'],
#  ['2405', '746', '36688', '48', '201', '452300'],
#  ['11354', '3929', '96536', '48', '201', '241300'],
#  ['4464', '1515', '53313', '48', '201', '253000'],
#  ['5322', '1754', '28750', '48', '201', '310900'],
#  ['7798', '2777', '59716', '48', '201', '552200'],
#  ['5335', '1633', '55618', '48', '113', '016517'],
#  ['4641', '1571', '47212', '48', '113', '017806'],
#  ['2219', '753', '61215', '48', '113', '017812'],
#  ['6067', '1571', '58607', '48', '113', '018105'],
#  ['4907', '2092', '75417', '48', '113', '018110'],
#  ['1178', '450', '38854', '48', '113', '018403'],
#  ['7811', '2648', '36860', '48', '113', '019019'],
#  ['7087', '2332', '58431', '48', '113', '019021'],
#  ['5555', '1955', '62612', '48', '113', '019027'],
#  ['3950', '1643', '102969', '48', '113', '019203'],
#  ['6827', '2669', '50075', '48', '113', '019206'],
#  ['5723', '2357', '54364', '48', '113', '019211'],
#  ['4268', '1123', '44861', '48', '113', '019900'],
#  ['3937', '1849', '114306', '48', '113', '000100'],
#  ['2038', '1120', '43142', '48', '113', '000405'],
#  ['6146', '3334', '50938', '48', '113', '000601'],
#  ['5016', '3269', '117083', '48', '113', '000701'],
#  ['3466', '1220', '21955', '48', '113', '002701'],
#  ['1296', '486', '31042', '48', '113', '004000'],
#  ['5041', '1747', '28671', '48', '113', '005700'],
#  ['4539', '1012', '54894', '48', '113', '006502'],
#  ['7341', '2040', '36465', '48', '113', '006700'],
#  ['2639', '1269', '52745', '48', '113', '007809'],
#  ['5678', '2393', '28994', '48', '113', '007818'],
#  ['6141', '1573', '45594', '48', '113', '009101'],
#  ['5058', '1460', '66829', '48', '113', '009701'],
#  ['9789', '2902', '34764', '48', '113', '010801'],
#  ['4177', '1322', '32442', '48', '113', '011104'],
#  ['8209', '2557', '33222', '48', '113', '012000'],
#  ['7869', '2758', '42441', '48', '113', '012207'],
#  ['4988', '1520', '41756', '48', '113', '012301'],
#  ['5990', '1930', '40590', '48', '113', '012701'],
#  ['2293', '957', '110341', '48', '113', '013618'],
#  ['3294', '1221', '54740', '48', '113', '009605'],
#  ['4859', '1906', '43992', '48', '201', '310300'],
#  ['7433', '2147', '44170', '48', '201', '311500'],
#  ['2600', '712', '43295', '48', '201', '311900'],
#  ['3325', '1689', '94337', '48', '201', '312500'],
#  ['2444', '1006', '42879', '48', '201', '313300'],
#  ['4897', '1553', '41701', '48', '201', '330400'],
#  ['9294', '2608', '50068', '48', '201', '321000'],
#  ['7850', '2176', '54627', '48', '201', '322700'],
#  ['7829', '3151', '51630', '48', '201', '323600'],
#  ['3906', '1382', '34270', '48', '201', '332400'],
#  ['10546', '3209', '34469', '48', '201', '333300'],
#  ['4836', '1484', '56983', '48', '189', '950400'],
#  ['3513', '1398', '40595', '48', '419', '950200'],
#  ['3233', '1301', '46655', '48', '419', '950600'],
#  ['4893', '1852', '38463', '48', '419', '950100'],
#  ['4831', '1588', '47361', '48', '419', '950300'],
#  ['5443', '1935', '26637', '48', '419', '950400'],
#  ['3565', '1218', '47717', '48', '419', '950500'],
#  ['4560', '1926', '35142', '48', '387', '950500'],
#  ['2895', '1106', '41776', '48', '387', '950600'],
#  ['2455', '1050', '37900', '48', '387', '950100'],
#  ['1958', '673', '50417', '48', '399', '950500'],
#  ['2521', '874', '33438', '48', '399', '950200'],
#  ['1307', '494', '49500', '48', '399', '950100'],
#  ['4524', '1708', '41711', '48', '399', '950600'],
#  ['4676', '2091', '41263', '48', '407', '200300'],
#  ['7190', '2179', '43131', '48', '407', '200101'],
#  ['11002', '3346', '50216', '48', '407', '200102'],
#  ['4951', '1871', '43882', '48', '407', '200200'],
#  ['3126', '1436', '38690', '48', '451', '001304'],
#  ['2237', '956', '49394', '48', '451', '000100'],
#  ['5292', '1958', '29470', '48', '451', '000400'],
#  ['5974', '2330', '49048', '48', '451', '001101'],
#  ['4509', '1837', '47668', '48', '451', '001303'],
#  ['4018', '1476', '44651', '48', '451', '000200'],
#  ['4581', '1656', '32569', '48', '451', '000700'],
#  ['6499', '2533', '39917', '48', '451', '001400'],
#  ['2701', '1045', '44363', '48', '451', '001702'],
#  ['4789', '1852', '46694', '48', '451', '001102'],
#  ['8390', '2769', '51392', '48', '451', '001200'],
#  ['7300', '2439', '49693', '48', '451', '001301'],
#  ['2782', '103', '44306', '48', '451', '001500'],
#  ['2255', '1028', '29049', '48', '451', '000900'],
#  ['5323', '2112', '59875', '48', '451', '001000'],
#  ['3661', '1382', '31579', '48', '143', '950600'],
#  ['7154', '2270', '53803', '48', '143', '950400'],
#  ['3072', '1052', '37500', '48', '463', '950100'],
#  ['3563', '1169', '45087', '48', '463', '950400'],
#  ['6021', '1807', '33671', '48', '463', '950500'],
#  ['6402', '1846', '48429', '48', '463', '950300'],
#  ['7951', '2809', '42686', '48', '463', '950200'],
#  ['2941', '1116', '60795', '48', '483', '950100'],
#  ['2541', '1138', '40179', '48', '483', '950300'],
#  ['4074', '1629', '24632', '48', '037', '010400'],
#  ['2429', '843', '17212', '48', '037', '010500'],
#  ['7255', '2823', '73014', '48', '037', '010901'],
#  ['7838', '2976', '49702', '48', '037', '011401'],
#  ['4922', '1918', '26744', '48', '037', '010800'],
#  ['1658', '715', '17431', '48', '037', '010600'],
#  ['5222', '2040', '40735', '48', '037', '010700'],
#  ['2489', '908', '58967', '48', '485', '012900'],
#  ['2085', '927', '24837', '48', '485', '011200'],
#  ['3038', '1124', '43061', '48', '485', '012700'],
#  ['5476', '2130', '60967', '48', '485', '013502'],
#  ['4019', '1726', '51083', '48', '485', '012600'],
#  ['5757', '2277', '45139', '48', '485', '013600'],
#  ['2721', '1322', '31875', '48', '485', '013700'],
#  ['3928', '1447', '73597', '48', '485', '013800'],
#  ['2252', '795', '24980', '48', '485', '010800'],
#  ['2441', '776', '38900', '48', '485', '011400'],
#  ['2363', '1000', '23229', '48', '485', '011000'],
#  ['1156', '465', '43750', '48', '345', '950100'],
#  ['1990', '701', '41705', '48', '129', '950200'],
#  ['1397', '589', '46125', '48', '129', '950300'],
#  ['2570', '839', '43262', '48', '013', '960500'],
#  ['5803', '1899', '54375', '48', '013', '960600'],
#  ['7849', '2105', '59263', '48', '013', '960201'],
#  ['3646', '1108', '37857', '48', '013', '960300'],
#  ['9039', '3048', '73004', '48', '013', '960402'],
#  ['7026', '2519', '60424', '48', '013', '960100'],
#  ['2331', '752', '50441', '48', '013', '960401'],
#  ['10564', '3117', '49931', '48', '013', '960202'],
#  ['4548', '1872', '42824', '48', '083', '950300'],
#  ['2621', '1064', '43333', '48', '083', '950700'],
#  ['1222', '524', '59375', '48', '083', '950600'],
#  ['2724', '1072', '57549', '48', '353', '950500'],
#  ['4278', '1584', '55000', '48', '353', '950200'],
#  ['1946', '764', '47500', '48', '353', '950100'],
#  ['1869', '630', '27212', '48', '353', '950300'],
#  ['4149', '1419', '30905', '48', '353', '950400'],
#  ['4434', '1550', '62961', '48', '475', '950100'],
#  ['4305', '1398', '77538', '48', '475', '950200'],
#  ['3552', '1234', '70714', '48', '143', '950100'],
#  ['8599', '2788', '29626', '48', '143', '950500'],
#  ['5793', '1874', '48569', '48', '143', '950300'],
#  ['1880', '782', '37717', '48', '143', '950700'],
#  ['11489', '3730', '101747', '48', '039', '660300'],
#  ['7242', '2337', '72321', '48', '039', '661000'],
#  ['3595', '1190', '53722', '48', '039', '661100'],
#  ['2976', '1108', '78830', '48', '039', '661700'],
#  ['7375', '2418', '72539', '48', '039', '662200'],
#  ['6288', '2417', '56250', '48', '039', '663800'],
#  ['5996', '2042', '51855', '48', '451', '000300'],
#  ['8986', '3278', '71127', '48', '451', '001704'],
#  ['4889', '1669', '73984', '48', '451', '001600'],
#  ['5432', '1675', '70115', '48', '459', '950700'],
#  ['4349', '1478', '37083', '48', '459', '950400'],
#  ['6039', '2120', '53500', '48', '459', '950500'],
#  ['4055', '1237', '67757', '48', '459', '950600'],
#  ['8550', '3072', '45774', '48', '459', '950300'],
#  ['8003', '2960', '51000', '48', '459', '950100'],
#  ['4341', '1494', '45750', '48', '459', '950200'],
#  ['3096', '590', '59615', '48', '309', '001800'],
#  ['10980', '3165', '52811', '48', '201', '333800'],
#  ['8147', '2705', '73198', '48', '201', '340700'],
#  ['4823', '1709', '79355', '48', '201', '343100'],
#  ['5233', '1680', '108258', '48', '201', '343200'],
#  ['6758', '1967', '55811', '48', '201', '350400'],
#  ['3837', '1478', '29045', '48', '201', '211400'],
#  ['6929', '1922', '31250', '48', '201', '211500'],
#  ['2749', '1086', '30102', '48', '201', '211600'],
#  ['5548', '1710', '43672', '48', '201', '320200'],
#  ['3307', '996', '69085', '48', '201', '321700'],
#  ['5772', '1700', '49440', '48', '201', '322600'],
#  ['5905', '1945', '31139', '48', '201', '323500'],
#  ['4263', '1215', '48616', '48', '201', '330200'],
#  ['5048', '1343', '50580', '48', '201', '330500'],
#  ['9909', '2479', '49702', '48', '201', '330700'],
#  ['3285', '1373', '26612', '48', '201', '331200'],
#  ['9730', '2974', '52926', '48', '201', '331500'],
#  ['3143', '937', '41406', '48', '201', '332300'],
#  ['4052', '1286', '43243', '48', '201', '333100'],
#  ['6360', '2122', '37418', '48', '201', '333500'],
#  ['4058', '1161', '63036', '48', '201', '333600'],
#  ['6769', '2084', '103111', '48', '201', '350300'],
#  ['5237', '2965', '123555', '48', '201', '410200'],
#  ['4041', '2424', '94960', '48', '201', '411300'],
#  ['3173', '1724', '87333', '48', '201', '411900'],
#  ['2847', '1008', '50551', '48', '475', '950300'],
#  ['2339', '937', '43789', '48', '213', '950500'],
#  ['3719', '1720', '42500', '48', '485', '011900'],
#  ['6715', '2904', '58750', '48', '485', '012400'],
#  ['2012', '890', '33148', '48', '485', '013000'],
#  ['944', '507', '18115', '48', '485', '010200'],
#  ['1365', '529', '18425', '48', '485', '010100'],
#  ['2713', '1085', '24793', '48', '485', '010700'],
#  ['5951', '2446', '57125', '48', '485', '012200'],
#  ['1312', '387', '62621', '48', '485', '013300'],
#  ['5561', '2377', '42316', '48', '485', '013501'],
#  ['1567', '669', '43622', '48', '485', '010900'],
#  ['6666', '2423', '59679', '48', '485', '013200'],
#  ['2792', '821', '46494', '48', '485', '011500'],
#  ['665', '261', '81985', '48', '033', '950100'],
#  ['4506', '1570', '53309', '48', '219', '950300'],
#  ['4598', '1498', '54773', '48', '219', '950200'],
#  ['1406', '497', '52063', '48', '219', '950700'],
#  ['5026', '1835', '48160', '48', '219', '950500'],
#  ['1430', '511', '63417', '48', '219', '950600'],
#  ['4804', '1532', '34315', '48', '219', '950400'],
#  ['1392', '503', '45536', '48', '219', '950100'],
#  ['2822', '1316', '35190', '48', '315', '950300'],
#  ['2611', '1051', '39840', '48', '315', '950400'],
#  ['2028', '892', '39631', '48', '315', '950100'],
#  ['2622', '1200', '32319', '48', '315', '950200'],
#  ['8690', '2294', '34917', '48', '323', '950201'],
#  ['4398', '1665', '40371', '48', '213', '950700'],
#  ['3393', '1515', '35893', '48', '213', '951100'],
#  ['8080', '3023', '46469', '48', '213', '950300'],
#  ['2551', '818', '30500', '48', '213', '951000'],
#  ['5645', '2076', '44221', '48', '213', '951300'],
#  ['4498', '1619', '56956', '48', '213', '950400'],
#  ['5069', '2225', '44988', '48', '213', '950800'],
#  ['7040', '2781', '59503', '48', '213', '951400'],
#  ['6374', '2658', '48765', '48', '213', '950100'],
#  ['6420', '1758', '30194', '48', '213', '951200'],
#  ['5500', '1906', '53448', '48', '213', '950200'],
#  ['5084', '1676', '38588', '48', '203', '020402'],
#  ['6092', '2516', '44000', '48', '203', '020200'],
#  ['5484', '1797', '50334', '48', '203', '020102'],
#  ['4221', '1418', '28150', '48', '203', '020401'],
#  ['2229', '840', '30283', '48', '277', '000600'],
#  ['5352', '2048', '45346', '48', '141', '004309'],
#  ['8510', '2784', '61521', '48', '141', '010207'],
#  ['3782', '1336', '54138', '48', '141', '010312'],
#  ['2736', '979', '65781', '48', '201', '420200'],
#  ['1993', '698', '79722', '48', '201', '423500'],
#  ['3966', '1208', '250001', '48', '201', '430600'],
#  ['4033', '1179', '31766', '48', '201', '433100'],
#  ['7115', '2802', '54663', '48', '201', '440100'],
#  ['4060', '1693', '118906', '48', '201', '450600'],
#  ['6507', '2177', '205391', '48', '201', '450700'],
#  ['4898', '2228', '66696', '48', '201', '454600'],
#  ['6203', '3215', '121592', '48', '201', '510600'],
#  ['7958', '4094', '149693', '48', '201', '510800'],
#  ['3420', '1155', '29497', '48', '201', '520400'],
#  ['2426', '741', '37644', '48', '201', '521000'],
#  ['6867', '2964', '28225', '48', '201', '521700'],
#  ['4113', '1728', '54195', '48', '253', '020500'],
#  ['2234', '1050', '53194', '48', '243', '950100'],
#  ['2730', '779', '34028', '48', '247', '950200'],
#  ['2552', '931', '30507', '48', '247', '950400'],
#  ['8400', '2450', '51522', '48', '249', '950200'],
#  ['6651', '2498', '42166', '48', '249', '950300'],
#  ['6453', '1963', '32182', '48', '249', '950500'],
#  ['3205', '986', '47829', '48', '249', '950700'],
#  ['8586', '2526', '51319', '48', '249', '950100'],
#  ['4209', '1452', '22680', '48', '249', '950600'],
#  ['3688', '1168', '53235', '48', '249', '950400'],
#  ['6684', '2116', '90595', '48', '339', '691900'],
#  ['5607', '1753', '40966', '48', '339', '690300'],
#  ['10713', '3275', '46479', '48', '339', '693000'],
#  ['8327', '2971', '76083', '48', '339', '694600'],
#  ['5872', '2403', '50450', '48', '339', '693500'],
#  ['11995', '3866', '124117', '48', '339', '694500'],
#  ['4342', '2091', '61603', '48', '339', '691500'],
#  ['4215', '1406', '28523', '48', '339', '693400'],
#  ['3829', '2022', '41201', '48', '339', '693600'],
#  ['11773', '4394', '88333', '48', '339', '693700'],
#  ['13140', '3656', '45920', '48', '339', '693900'],
#  ['4239', '1560', '144052', '48', '339', '690800'],
#  ['19479', '6491', '81911', '48', '339', '692300'],
#  ['10658', '3998', '65155', '48', '339', '692400'],
#  ['8370', '2849', '96691', '48', '339', '693200'],
#  ['7879', '3277', '68914', '48', '339', '693300'],
#  ['4791', '1707', '41539', '48', '339', '693800'],
#  ['1937', '730', '68289', '48', '167', '721000'],
#  ['3308', '1452', '31294', '48', '167', '723000'],
#  ['7068', '2595', '71781', '48', '167', '723400'],
#  ['4180', '2016', '93083', '48', '167', '723800'],
#  ['2995', '927', '33393', '48', '141', '003803'],
#  ['4143', '2030', '19150', '48', '141', '001600'],
#  ['4293', '1451', '25471', '48', '141', '003502'],
#  ['5644', '1857', '70938', '48', '141', '001110'],
#  ['5807', '2100', '52679', '48', '141', '004307'],
#  ['3950', '1557', '55262', '48', '113', '004201'],
#  ['2223', '965', '65451', '48', '113', '004202'],
#  ['2585', '781', '37104', '48', '113', '004800'],
#  ['3899', '1466', '24704', '48', '113', '004900'],
#  ['4809', '1348', '36199', '48', '113', '005500'],
#  ['5568', '1996', '28664', '48', '113', '005901'],
#  ['5240', '1176', '35294', '48', '113', '006001'],
#  ['4802', '1409', '50907', '48', '113', '006302'],
#  ['5227', '1847', '43598', '48', '113', '006800'],
#  ['5582', '2375', '52479', '48', '113', '007102'],
#  ['7880', '2455', '32480', '48', '113', '007201'],
#  ['2115', '1166', '84833', '48', '113', '007801'],
#  ['6250', '3264', '85290', '48', '113', '008100'],
#  ['5378', '1303', '51140', '48', '113', '008500'],
#  ['747', '234', '24792', '48', '113', '008603'],
#  ['3004', '1173', '20916', '48', '113', '008604'],
#  ['3874', '1605', '56985', '48', '423', '001101'],
#  ['3633', '1388', '51152', '48', '105', '950100'],
#  ['4154', '1345', '68656', '48', '199', '030600'],
#  ['4369', '1542', '62936', '48', '199', '030900'],
#  ['2234', '775', '49856', '48', '199', '030400'],
#  ['4560', '1490', '84063', '48', '199', '030501'],
#  ['4100', '1490', '39485', '48', '199', '030700'],
#  ['8368', '3046', '65287', '48', '199', '030502'],
#  ['3867', '1566', '38750', '48', '199', '030800'],
#  ['3145', '1229', '40913', '48', '199', '030100'],
#  ['6122', '2140', '69531', '48', '199', '030200'],
#  ['3686', '1459', '60354', '48', '199', '031000'],
#  ['11774', '4303', '61700', '48', '199', '030300'],
#  ['3759', '1302', '47385', '48', '207', '950300'],
#  ['2050', '823', '35125', '48', '207', '950400'],
#  ['3887', '1287', '52031', '48', '227', '950700'],
#  ['3301', '1395', '30430', '48', '227', '950400'],
#  ['3395', '1113', '48386', '48', '227', '950500'],
#  ['4658', '1412', '60000', '48', '227', '950600'],
#  ['4199', '1466', '81477', '48', '227', '950900'],
#  ['2442', '875', '53688', '48', '227', '950100'],
#  ['2435', '557', '26406', '48', '227', '950300'],
#  ['1944', '741', '50125', '48', '227', '950200'],
#  ['5521', '2102', '53269', '48', '289', '950200'],
#  ['6493', '2124', '39123', '48', '289', '950100'],
#  ['1299', '559', '41513', '48', '167', '724800'],
#  ['3184', '1181', '26520', '48', '167', '722200'],
#  ['5444', '2015', '66297', '48', '167', '721300'],
#  ['2640', '1027', '42310', '48', '167', '722900'],
#  ['1862', '844', '42845', '48', '167', '725000'],
#  ['2350', '1176', '90595', '48', '167', '726100'],
#  ['4801', '1783', '110625', '48', '167', '720200'],
#  ['7600', '2377', '190250', '48', '167', '720400'],
#  ['9378', '3283', '39924', '48', '167', '721700'],
#  ['10807', '3743', '43559', '48', '167', '721900'],
#  ['2324', '862', '35350', '48', '167', '723700'],
#  ['1645', '713', '51484', '48', '167', '724900'],
#  ['1958', '712', '42879', '48', '167', '725100'],
#  ['2216', '826', '53111', '48', '167', '725300'],
#  ['4952', '1769', '41971', '48', '167', '722700'],
#  ['4460', '1439', '64089', '48', '167', '723200'],
#  ['3982', '248', '37000', '48', '167', '724000'],
#  ['2932', '1431', '40625', '48', '167', '724400'],
#  ['1791', '716', '15625', '48', '167', '724600'],
#  ['1726', '711', '27642', '48', '167', '724700'],
#  ['1152', '512', '76429', '48', '167', '725500'],
#  ['2216', '772', '58409', '48', '167', '721600'],
#  ['4206', '1676', '53116', '48', '167', '725800'],
#  ['1395', '599', '69688', '48', '167', '726000'],
#  ['7893', '3170', '100957', '48', '167', '721400'],
#  ['2574', '895', '43199', '48', '167', '722600'],
#  ['3402', '1424', '41400', '48', '167', '723100'],
#  ['6685', '2273', '88156', '48', '167', '723300'],
#  ['2333', '1035', '43454', '48', '167', '723900'],
#  ['2208', '669', '34375', '48', '201', '220100'],
#  ['9861', '2529', '48638', '48', '201', '221600'],
#  ['3148', '872', '33110', '48', '201', '222800'],
#  ['4937', '1695', '30090', '48', '201', '230200'],
#  ['7687', '2265', '36008', '48', '201', '231900'],
#  ['6572', '2285', '64554', '48', '201', '251200'],
#  ['6551', '2078', '88558', '48', '201', '251600'],
#  ['9964', '3364', '52114', '48', '201', '253500'],
#  ['1843', '575', '46773', '48', '201', '254500'],
#  ['3446', '1154', '57455', '48', '201', '254600'],
#  ['4507', '1367', '41513', '48', '201', '310500'],
#  ['1541', '495', '49450', '48', '201', '311400'],
#  ['2792', '1063', '27775', '48', '201', '240600'],
#  ['7660', '2719', '50735', '48', '201', '241200'],
#  ['8403', '3178', '38293', '48', '201', '250600'],
#  ['3094', '1192', '91786', '48', '201', '251000'],
#  ['2148', '708', '90119', '48', '201', '251800'],
#  ['5084', '2023', '54282', '48', '289', '950300'],
#  ['1697', '622', '45278', '48', '333', '950100'],
#  ['3205', '1128', '41012', '48', '333', '950200'],
#  ['2420', '1082', '51250', '48', '337', '950100'],
#  ['7297', '2536', '82132', '48', '135', '001700'],
#  ['5260', '1767', '81321', '48', '135', '002400'],
#  ['7370', '2477', '88575', '48', '135', '002501'],
#  ['3221', '1179', '54527', '48', '135', '000800'],
#  ['3940', '1693', '66971', '48', '135', '002300'],
#  ['6364', '2267', '63627', '48', '135', '002502'],
#  ['10931', '3451', '54809', '48', '135', '002700'],
#  ['5565', '1740', '69417', '48', '135', '001000'],
#  ['5066', '1681', '63836', '48', '135', '001300'],
#  ['6031', '2063', '71516', '48', '135', '001600'],
#  ['6455', '2651', '65213', '48', '135', '002503'],
#  ['1714', '663', '49531', '48', '135', '000300'],
#  ['5838', '1718', '52264', '48', '135', '000600'],
#  ['3288', '1084', '59333', '48', '135', '002200'],
#  ['7793', '2495', '53365', '48', '135', '001100'],
#  ['5379', '1378', '57917', '48', '135', '002801'],
#  ['11835', '3695', '91439', '48', '135', '003000'],
#  ['5279', '1553', '90299', '48', '135', '000400'],
#  ['5188', '1675', '63278', '48', '135', '000500'],
#  ['3908', '1211', '36626', '48', '135', '001800'],
#  ['5721', '1655', '38606', '48', '135', '001900'],
#  ['4023', '1261', '41234', '48', '135', '002000'],
#  ['3340', '1366', '86100', '48', '135', '002900'],
#  ['9968', '2695', '53096', '48', '135', '002802'],
#  ['6288', '1628', '55039', '48', '169', '950100'],
#  ['5330', '1766', '49323', '48', '037', '010100'],
#  ['5432', '2094', '45179', '48', '037', '011300'],
#  ['2202', '826', '49605', '48', '037', '011402'],
#  ['5278', '1988', '41053', '48', '037', '011600'],
#  ['7800', '2256', '58432', '48', '037', '011100'],
#  ['8190', '3177', '48065', '48', '037', '010902'],
#  ['6312', '2102', '109107', '48', '037', '011200'],
#  ['2185', '980', '50179', '48', '037', '011700'],
#  ['7093', '2604', '48944', '48', '037', '011000'],
#  ['2988', '1080', '97500', '48', '009', '020100'],
#  ['2322', '926', '56053', '48', '009', '020200'],
#  ['3479', '1326', '49231', '48', '009', '020300'],
#  ['1862', '715', '37083', '48', '043', '950400'],
#  ['4602', '2023', '44305', '48', '043', '950300'],
#  ['749', '318', '45926', '48', '263', '950100'],
#  ['2792', '1114', '61500', '48', '077', '030302'],
#  ['3043', '1157', '45117', '48', '077', '030200'],
#  ['5767', '1681', '59280', '48', '205', '950200'],
#  ['2274', '698', '62375', '48', '201', '252100'],
#  ['9502', '3047', '56174', '48', '201', '252200'],
#  ['2328', '678', '42206', '48', '469', '000100'],
#  ['1790', '738', '60417', '48', '469', '000400'],
#  ['1981', '702', '64519', '48', '469', '000800'],
#  ['4778', '1823', '35666', '48', '469', '000602'],
#  ['2240', '812', '58710', '48', '469', '001300'],
#  ['3594', '1233', '89583', '48', '469', '001501'],
#  ['6593', '2112', '71346', '48', '469', '001604'],
#  ['2066', '608', '26000', '48', '469', '000301'],
#  ['6120', '2164', '61260', '48', '469', '001601'],
#  ['2897', '1119', '34095', '48', '469', '000601'],
#  ['3126', '1294', '54940', '48', '469', '001605'],
#  ['2958', '1025', '24530', '48', '469', '000201'],
#  ['4076', '1547', '44741', '48', '469', '000502'],
#  ['3989', '1491', '48990', '48', '469', '000700'],
#  ['8314', '3057', '77023', '48', '469', '001400'],
#  ['2187', '630', '33204', '48', '469', '000302'],
#  ['3518', '1222', '40906', '48', '469', '001700'],
#  ['4366', '1623', '47547', '48', '469', '000501'],
#  ['6211', '1823', '42632', '48', '469', '000202'],
#  ['6196', '1810', '105602', '48', '473', '680100'],
#  ['9625', '3055', '49799', '48', '473', '680200'],
#  ['10183', '3377', '48015', '48', '473', '680300'],
#  ['8689', '2710', '78258', '48', '473', '680600'],
#  ['4157', '1303', '55977', '48', '039', '663000'],
#  ['5810', '2147', '63650', '48', '039', '664100'],
#  ['6678', '2185', '87478', '48', '039', '660200'],
#  ['5481', '2083', '77566', '48', '039', '662100'],
#  ['3563', '1308', '66972', '48', '039', '662600'],
#  ['5194', '1871', '120083', '48', '039', '663600'],
#  ['6937', '2408', '54326', '48', '039', '661400'],
#  ['7648', '2059', '127773', '48', '039', '663100'],
#  ['2146', '981', '47589', '48', '039', '664200'],
#  ['10756', '3646', '99322', '48', '039', '660400'],
#  ['4402', '1588', '44881', '48', '039', '661200'],
#  ['2454', '904', '62188', '48', '039', '662700'],
#  ['2202', '763', '62250', '48', '039', '663300'],
#  ['6122', '2208', '73415', '48', '039', '663500'],
#  ['2361', '840', '44722', '48', '039', '663900'],
#  ['2460', '879', '40592', '48', '039', '661300'],
#  ['7684', '3094', '74735', '48', '039', '663400'],
#  ['5211', '1937', '54973', '48', '039', '662300'],
#  ['5040', '1999', '56723', '48', '039', '662400'],
#  ['6372', '2299', '63576', '48', '039', '662800'],
#  ['7612', '2256', '60833', '48', '039', '660900'],
#  ['1403', '470', '35833', '48', '217', '960600'],
#  ['3442', '1356', '44464', '48', '217', '960800'],
#  ['4488', '1708', '59265', '48', '217', '960200'],
#  ['3706', '1364', '52703', '48', '217', '960100'],
#  ['3668', '1197', '62138', '48', '217', '961100'],
#  ['2015', '626', '36603', '48', '217', '961000'],
#  ['5958', '2390', '51850', '48', '217', '960500'],
#  ['2089', '719', '50446', '48', '217', '960700'],
#  ['1959', '774', '39375', '48', '217', '960400'],
#  ['2027', '638', '33375', '48', '217', '960900'],
#  ['2175', '514', '41667', '48', '293', '970400'],
#  ['2226', '690', '40000', '48', '293', '970100'],
#  ['3901', '1441', '49680', '48', '293', '970200'],
#  ['2335', '845', '32369', '48', '293', '970300'],
#  ['5764', '1993', '39890', '48', '293', '970600'],
#  ['1913', '685', '34144', '48', '293', '970500'],
#  ['3423', '1311', '46444', '48', '293', '970800'],
#  ['4954', '2018', '52917', '48', '277', '000900'],
#  ['4300', '933', '38666', '48', '201', '232500'],
#  ['3210', '916', '62167', '48', '201', '232600'],
#  ['9781', '3033', '71552', '48', '201', '241400'],
#  ['12874', '3829', '67739', '48', '201', '542400'],
#  ['3892', '1051', '70050', '48', '201', '550700'],
#  ['2665', '819', '70893', '48', '495', '950200'],
#  ['1177', '414', '70000', '48', '495', '950400'],
#  ['3960', '1339', '47229', '48', '495', '950300'],
#  ['4274', '1072', '62167', '48', '201', '321800'],
#  ['4620', '1849', '27246', '48', '201', '313600'],
#  ['4585', '1256', '60656', '48', '201', '320500'],
#  ['2965', '904', '30263', '48', '201', '321500'],
#  ['5460', '1790', '39026', '48', '201', '331300'],
#  ['3665', '1153', '46277', '48', '201', '331900'],
#  ['6191', '1928', '28562', '48', '201', '332000'],
#  ['5229', '1412', '46384', '48', '201', '332200'],
#  ['3268', '1235', '71908', '48', '201', '341700'],
#  ['3772', '1162', '60625', '48', '201', '342200'],
#  ['3358', '1198', '63750', '48', '201', '342400'],
#  ['17237', '5203', '92357', '48', '201', '350100'],
#  ['1596', '541', '211250', '48', '201', '412500'],
#  ['4215', '2530', '61948', '48', '201', '410800'],
#  ['2869', '1628', '71735', '48', '201', '410900'],
#  ['3164', '1063', '243583', '48', '201', '413100'],
#  ['2348', '833', '184205', '48', '201', '420800'],
#  ['7061', '2491', '236797', '48', '201', '420900'],
#  ['5983', '2835', '83708', '48', '201', '430100'],
#  ['7580', '3447', '38804', '48', '201', '432300'],
#  ['15562', '2876', '78654', '48', '039', '661900'],
#  ['3930', '1389', '65433', '48', '039', '664000'],
#  ['4975', '1660', '106548', '48', '039', '660100'],
#  ['9591', '3388', '85245', '48', '039', '660500'],
#  ['5858', '1754', '39015', '48', '039', '664300'],
#  ['2986', '988', '90658', '48', '039', '662500'],
#  ['4721', '1979', '68708', '48', '039', '663200'],
#  ['3573', '1267', '89779', '48', '039', '663700'],
#  ['6042', '2209', '38107', '48', '039', '664400'],
#  ['6163', '2066', '79113', '48', '039', '661800'],
#  ['6249', '2262', '70487', '48', '039', '662000'],
#  ['5111', '1772', '59891', '48', '039', '662900'],
#  ['11284', '3847', '42513', '48', '473', '680500'],
#  ['4010', '8', '-666666666', '48', '473', '680400'],
#  ['4078', '1419', '42075', '48', '481', '741000'],
#  ['4325', '1564', '59273', '48', '481', '740600'],
#  ['1259', '454', '30781', '48', '481', '740300'],
#  ['1645', '635', '31583', '48', '481', '740700'],
#  ['2552', '900', '65500', '48', '481', '741100'],
#  ['1823', '583', '48385', '48', '481', '740200'],
#  ['5802', '2220', '44110', '48', '481', '740400'],
#  ['7250', '2748', '65041', '48', '481', '740900'],
#  ['3486', '1346', '31524', '48', '481', '740500'],
#  ['5461', '2046', '54483', '48', '481', '740100'],
#  ['3870', '1341', '38438', '48', '481', '740800'],
#  ['1891', '914', '19034', '48', '485', '010400'],
#  ['1088', '483', '39875', '48', '485', '011300'],
#  ['1888', '817', '56172', '48', '485', '011800'],
#  ['2875', '1168', '42059', '48', '485', '012100'],
#  ['1233', '522', '27237', '48', '485', '011100'],
#  ['4439', '1705', '57135', '48', '485', '012800'],
#  ['2208', '966', '59500', '48', '485', '011700'],
#  ['6806', '2683', '48612', '48', '485', '012000'],
#  ['8038', '2810', '80556', '48', '485', '012300'],
#  ...]

# %%
#store response into dataframe
census_result_df=pd.DataFrame(response.json(), columns=response.json()[0])

#remove duplicate header row
census_result_df=census_result_df.drop(axis=0,index=0)

#rename columns 
census_result_df=census_result_df.rename(columns={"S0101_C01_001E":"Total_Popupation",
                                                  "S1101_C01_001E":"Total_Households",
                                                  "S1901_C01_012E":"Median_Household_Income",
                                                  "state":"state_fips",
                                                  "county":"county_fips",
                                                  "tract":"tract_code"
                                                 })

#set index to tract_code and sort 
census_result_df=census_result_df.set_index("tract_code")[["Total_Popupation", "Total_Households", "Median_Household_Income"]]

census_result_df
# Out:
#            Total_Popupation Total_Households Median_Household_Income
# tract_code
# 020701                 1302              686                   14569
# 021202                 4354             1599                   46481
# 021303                 9873             3538                   69833
# 021901                 3825             1304                   54441
# 022600                 4308             1745                   28423
# ...                     ...              ...                     ...
# 000203                 1890              816                   68611
# 000802                 3561             1314                   44323
# 001740                 5093             2023                  101989
# 001839                 8762             3524                   68269
# 001800                 2722              877                   25540
#
# [5265 rows x 3 columns]

# %%
#joining census data by tract
full_data = pd.merge(crime_data, census_result_df, left_on="Tract", right_on="tract_code", how="left")
full_data

# %%
#saving data to csv
full_data.to_csv("final_dataset.csv")
