# %%
import pandas as pd

# %%
data_csv = 'final_dataset.csv'

full_data = pd.read_csv(data_csv)

full_data
# Out:
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0        Date  Hour      Offense_Type  Offense_Count  \
# 0                0  01/01/2018     0  Burglary/Robbery            1.0
# 1                1  01/01/2018     0  Burglary/Robbery            1.0
# 2                2  01/01/2018     0  Burglary/Robbery            1.0
# 3                3  01/01/2018     0           Assault            2.0
# 4                4  01/01/2018     0             Theft            1.0
# ...            ...         ...   ...               ...            ...
# 406415      406415     5/31/20    23             Theft            1.0
# 406416      406416     5/31/20    23             Theft            1.0
# 406417      406417     5/31/20    23      Intimidation            1.0
# ...

# %%
# counts = full_data['Tract'].value_counts()

# full_data = full_data[~full_data['Tract'].isin(counts[counts < 2].index)]

full_data.columns

# full_data['Tract'].unique()

# full_data['Tract'].value_counts()
# Out:
# Index(['Unnamed: 0', 'Date', 'Hour', 'Offense_Type', 'Offense_Count',
#        'Premise', 'Block_Range', 'Street_Name', 'Street_Type', 'City', 'State',
#        'Street_Address', 'Full_Address', 'Latitude', 'Longitude', 'Tract',
#        'Year', 'Month', 'Day', 'Week_Num', 'Day_of_Week', 'Temperature',
#        'Precipitation', 'Weather', 'Weather_Description', 'Total_Popupation',
#        'Total_Households', 'Median_Household_Income'],
#       dtype='object')

# %%
cleaned_data = full_data.dropna()

cleaned_data
# Out:
#         Unnamed: 0        Date  Hour      Offense_Type  Offense_Count  \
# 0                0  01/01/2018     0  Burglary/Robbery            1.0
# 1                1  01/01/2018     0  Burglary/Robbery            1.0
# 2                2  01/01/2018     0  Burglary/Robbery            1.0
# 3                3  01/01/2018     0           Assault            2.0
# 4                4  01/01/2018     0             Theft            1.0
# ...            ...         ...   ...               ...            ...
# 406411      406411     5/31/20    23             Theft            1.0
# 406413      406413     5/31/20    23      Intimidation            0.0
# 406414      406414     5/31/20    23             Theft            1.0
# 406417      406417     5/31/20    23      Intimidation            1.0
# 406419      406419     5/31/20    23             Theft            1.0
#
#                                          Premise Block_Range  \
# 0                             Residence or House        1300
# ...

# %%
cleaned_data['Tract']
# Out:
# 0         313100.0
# 1         321300.0
# 2         432801.0
# 3         330700.0
# 4         312800.0
#             ...
# 406411    521700.0
# 406413    521200.0
# 406414    521200.0
# 406417    431102.0
# 406419    521900.0
# Name: Tract, Length: 309959, dtype: float64

# %%
# For any columns we want to remove the .0 from
cleaned_data['Tract'] = cleaned_data['Tract'].apply(lambda f: format(f, '.0f'))

cleaned_data
# Out:
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Unnamed: 0        Date  Hour      Offense_Type  Offense_Count  \
# 0                0  01/01/2018     0  Burglary/Robbery            1.0
# 1                1  01/01/2018     0  Burglary/Robbery            1.0
# 2                2  01/01/2018     0  Burglary/Robbery            1.0
# 3                3  01/01/2018     0           Assault            2.0
# 4                4  01/01/2018     0             Theft            1.0
# ...            ...         ...   ...               ...            ...
# 406411      406411     5/31/20    23             Theft            1.0
# ...

# %%
cleaned_data['Tract']
# Out:
# 0         313100
# 1         321300
# 2         432801
# 3         330700
# 4         312800
#            ...
# 406411    521700
# 406413    521200
# 406414    521200
# 406417    431102
# 406419    521900
# Name: Tract, Length: 309959, dtype: object

# %%
cleaned_data.to_csv('cleaned_data.csv')

# %%
mach_learn_df = cleaned_data[['Hour', 'Offense_Type',
       'Premise', 'City',
       'Tract',
       'Month', 'Day_of_Week', 'Temperature',
       'Weather']]

mach_learn_df
# Out:
#         Hour      Offense_Type                                   Premise  \
# 0          0  Burglary/Robbery                        Residence or House
# 1          0  Burglary/Robbery                                 Apartment
# 2          0  Burglary/Robbery                 Road, Street, or Sidewalk
# 3          0           Assault                 Road, Street, or Sidewalk
# 4          0             Theft  Church, Synagogue, or Temple Parking Lot
# ...      ...               ...                                       ...
# 406411    23             Theft      Residence, Home (Includes Apartment)
# 406413    23      Intimidation      Residence, Home (Includes Apartment)
# 406414    23             Theft                      Bank, Savings & Loan
# 406417    23      Intimidation      Residence, Home (Includes Apartment)
# 406419    23             Theft                       Parking Lot, Garage
#
#            City   Tract  Month Day_of_Week  Temperature Weather
# ...

# %%
mach_learn_df['City'].unique()
# Out:
# array(['Houston', 'HUMBLE', 'SOUTH+Houston', 'WALLER', 'STAFFORD',
#        'PASADENA', 'KINGWOOD', 'LEAGUE+CITY', 'WEBSTER', 'BELLAIRE',
#        'BAYTOWN', 'HUFFMAN', 'ROSENBERG', 'MISSOURI+CITY', 'PEARLAND',
#        'RICHMOND', 'CYPRESS', 'GALENA+PARK', 'FRIENDSWOOD',
#        'THE+WOODLANDS', 'JACINTO+CITY', 'SPRING'], dtype=object)

# %%
mach_learn_df['City'] = mach_learn_df['City'].str.replace('+', ' ', regex=True)

mach_learn_df
# Out:
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Hour      Offense_Type                                   Premise  \
# 0          0  Burglary/Robbery                        Residence or House
# 1          0  Burglary/Robbery                                 Apartment
# 2          0  Burglary/Robbery                 Road, Street, or Sidewalk
# 3          0           Assault                 Road, Street, or Sidewalk
# 4          0             Theft  Church, Synagogue, or Temple Parking Lot
# ...      ...               ...                                       ...
# ...

# %%
mach_learn_df['City'].unique()
# Out:
# array(['Houston', 'HUMBLE', 'SOUTH Houston', 'WALLER', 'STAFFORD',
#        'PASADENA', 'KINGWOOD', 'LEAGUE CITY', 'WEBSTER', 'BELLAIRE',
#        'BAYTOWN', 'HUFFMAN', 'ROSENBERG', 'MISSOURI CITY', 'PEARLAND',
#        'RICHMOND', 'CYPRESS', 'GALENA PARK', 'FRIENDSWOOD',
#        'THE WOODLANDS', 'JACINTO CITY', 'SPRING'], dtype=object)

# %%
mach_learn_df.to_csv('mach_learn_df.csv')
