# %%
import pandas as pd

# %%
# Clean 2020 Jan - May crime data

crime_2020_df = pd.read_csv("raw_data/2020_1-5_Jan-May.csv")
crime_2020_df = crime_2020_df.rename(columns={"Occurrence\nDate": "Date", 
                                              "Occurrence\nHour": "Hour",
                                              "NIBRS\nClass": "NIBRS_Class",
                                              "NIBRSDescription": "Offense_Type",
                                              "Offense\nCount": "Offense_Count",
                                              "Block Range": "Block_Range",
                                              "StreetName": "Street_Name",
                                              "Street\nType": "Street_Type",
                                              "ZIP Code": "Zip_Code"})
crime_2020_df.columns
# Out:
# Index(['Incident', 'Date', 'Hour', 'NIBRS_Class', 'Offense_Type',
#        'Offense_Count', 'Beat', 'Premise', 'Block_Range', 'Street_Name',
#        'Street_Type', 'Suffix', 'City', 'Zip_Code'],
#       dtype='object')

# %%
# Only take 2020 data we need
crime_2020_df = crime_2020_df[['Date','Hour','Offense_Type','Offense_Count','Premise','Block_Range','Street_Name','Street_Type','City']]
crime_2020_df.head()
# Out:
#      Date  Hour                               Offense_Type  Offense_Count  \
# 0  1/1/20     0  Theft of motor vehicle parts or accessory              1
# 1  1/1/20     0                         Aggravated Assault              1
# 2  1/1/20     0             Destruction, damage, vandalism              1
# 3  1/1/20     0                             Simple assault              1
# 4  1/1/20     0             Destruction, damage, vandalism              1
#
#                                 Premise Block_Range Street_Name Street_Type  \
# 0  Residence, Home (Includes Apartment)        9311  BELLA PINE          CT
# 1  Residence, Home (Includes Apartment)        8701     GUSTINE          LN
# 2  Residence, Home (Includes Apartment)        8064      LENORE         NaN
# 3  Residence, Home (Includes Apartment)        5930    DASHWOOD          DR
# 4  Residence, Home (Includes Apartment)        5218   KENILWOOD          DR
#
#       City
# 0  HOUSTON
# 1  HOUSTON
# 2  HOUSTON
# 3  HOUSTON
# ...

# %%
# Clean 2019 Jan - Dec crime data

crime_2019_df = pd.read_csv("raw_data/2019_1-12_Jan-Dec.csv")
crime_2019_df = crime_2019_df.rename(columns={"Occurrence\nDate": "Date", 
                                              "Occurrence\nHour": "Hour",
                                              "NIBRS\nClass": "NIBRS_Class",
                                              "NIBRSDescription": "Offense_Type",
                                              "Offense\nCount": "Offense_Count",
                                              "Block Range": "Block_Range",
                                              "StreetName": "Street_Name",
                                              "Street\nType": "Street_Type",
                                              "ZIP Code": "Zip_Code"})
crime_2019_df.columns
# Out:
# Index(['Incident', 'Date', 'Hour', 'NIBRS_Class', 'Offense_Type',
#        'Offense_Count', 'Beat', 'Premise', 'Block_Range', 'Street_Name',
#        'Street_Type', 'Suffix', 'City', 'Zip_Code'],
#       dtype='object')

# %%
# Only take 2019 data we need
crime_2019_df = crime_2019_df[['Date','Hour','Offense_Type','Offense_Count','Premise','Block_Range','Street_Name','Street_Type','City']]
crime_2019_df
# Out:
#             Date  Hour                    Offense_Type  Offense_Count  \
# 0         1/1/19     0  Destruction, damage, vandalism              1
# 1         1/1/19     0       Drug, narcotic violations              1
# 2         1/1/19     0  Destruction, damage, vandalism              1
# 3         1/1/19     0           Weapon law violations              1
# 4         1/1/19     0              Aggravated Assault              1
# ...          ...   ...                             ...            ...
# 219029  12/31/19    23                  Simple assault              1
# 219030  12/31/19    23              Aggravated Assault              1
# 219031  12/31/19    23                     Shoplifting              1
# 219032  12/31/19    23                    Intimidation              1
# 219033  12/31/19    23       Drug, narcotic violations              1
#
#                                      Premise Block_Range Street_Name  \
# ...

# %%
# Clean 2018 Jan - May crime data
# Need to seperate 2018 data from first half and second half of the year due to different formatting of columns 

all_files = ["raw_data/2018_1_Jan.csv", 
            "raw_data/2018_2_Feb.csv",
            "raw_data/2018_3_Mar.csv",
            "raw_data/2018_4_Apr.csv",
            "raw_data/2018_5_May.csv"]

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

crime_2018_Jan_May_df = pd.concat(li, axis=0, ignore_index=True)
crime_2018_Jan_May_df = crime_2018_Jan_May_df.rename(columns={"Offense Type": "Offense_Type",
                                                              "Block Range": "Block_Range",
                                                              "Street Name": "Street_Name",
                                                              "Street\nType": "Street_Type",
                                                              "Type": "Street_Type",
                                                              "Offenses": "Offense_Count"})
crime_2018_Jan_May_df.columns
# Out:
# Index(['Date', 'Hour', 'Offense_Type', 'Beat', 'Premise', 'Block_Range',
#        'Street_Name', 'Street_Type', 'Suffix', 'Offense_Count'],
#       dtype='object')

# %%
# Only take 2018 Jan-May data we need
crime_2018_Jan_May_df = crime_2018_Jan_May_df[['Date','Hour','Offense_Type','Offense_Count','Premise','Block_Range','Street_Name','Street_Type']]
crime_2018_Jan_May_df['City'] = 'HOUSTON'
crime_2018_Jan_May_df
# Out:
#              Date  Hour Offense_Type  Offense_Count  \
# 0      01/01/2018  18.0      Robbery            1.0
# 1      01/01/2018  18.0        Theft            1.0
# 2      01/02/2018  14.0        Theft            1.0
# 3      01/04/2018   8.0     Burglary            1.0
# 4      01/04/2018  18.0        Theft            1.0
# ...           ...   ...          ...            ...
# 47015  05/28/2018  22.0        Theft            1.0
# 47016  05/28/2018  22.0        Theft            1.0
# 47017  05/30/2018  23.0    AutoTheft            1.0
# 47018  05/30/2018   5.0        Theft            1.0
# 47019         NaN   NaN          NaN            NaN
#
#                             Premise  Block_Range   Street_Name Street_Type  \
# 0        Field, Woods, Forest, Park      200-299         LENOX           -
# 1         Road, Street, or Sidewalk    3700-3799  HOUSTON LAKE          DR
# 2                       Auto Repair  16700-16799        EASTEX           -
# ...

# %%
# Clean 2018 June - Dec crime data

all_files = ["raw_data/2018_6_Jun.csv", 
            "raw_data/2018_7_Jul.csv",
            "raw_data/2018_8_Aug.csv",
            "raw_data/2018_9_Sep.csv",
            "raw_data/2018_10_Oct.csv",
            "raw_data/2018_11_Nov.csv",
            "raw_data/2018_12_Dec.csv"]

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

crime_2018_Jun_Dec_df = pd.concat(li, axis=0, ignore_index=True)
crime_2018_Jun_Dec_df = crime_2018_Jun_Dec_df.rename(columns={"Occurrence Date": "Date",
                                                              "Occurrence Hour": "Hour",
                                                              "NIBRS Description": "Offense_Type",
                                                              "Offense Count": "Offense_Count",
                                                              "Block Range": "Block_Range",
                                                              "Street Name": "Street_Name",
                                                              "Street Type": "Street_Type"})
crime_2018_Jun_Dec_df.columns
# Out:
# Index(['Date', 'Hour', 'Offense_Type', 'Unnamed: 3', 'Offense_Count', 'Beat',
#        'Premise', 'Block_Range', 'Street_Name', 'Street_Type', 'Suffix'],
#       dtype='object')

# %%
# Only take 2018 Jun-Dec data we need
crime_2018_Jun_Dec_df = crime_2018_Jun_Dec_df[['Date','Hour','Offense_Type','Offense_Count','Premise','Block_Range','Street_Name','Street_Type']]
crime_2018_Jun_Dec_df['City'] = 'HOUSTON'
crime_2018_Jun_Dec_df
# Out:
#             Date  Hour                     Offense_Type  Offense_Count  \
# 0         6/1/18     0                   Simple assault              1
# 1         6/1/18     0         False pretenses, swindle              1
# 2         6/1/18     0               All other offenses              1
# 3         6/1/18     0              Motor vehicle theft              1
# 4         6/1/18     0  Burglary, Breaking and Entering              1
# ...          ...   ...                              ...            ...
# 145708  12/31/18    23               Aggravated Assault              1
# 145709  12/31/18    23      Driving under the influence              1
# 145710  12/31/18    23      Driving under the influence              1
# 145711  12/31/18    23        Drug, narcotic violations              1
# 145712  12/31/18    23               Disorderly conduct              1
#
#                                      Premise Block_Range   Street_Name  \
# ...

# %%
clean_crime_data_df = pd.concat([crime_2020_df, 
                                 crime_2019_df,
                                 crime_2018_Jan_May_df, 
                                 crime_2018_Jun_Dec_df,], ignore_index=True)

# %%
clean_crime_data_df
# Out:
#             Date  Hour                               Offense_Type  \
# 0         1/1/20   0.0  Theft of motor vehicle parts or accessory
# 1         1/1/20   0.0                         Aggravated Assault
# 2         1/1/20   0.0             Destruction, damage, vandalism
# 3         1/1/20   0.0                             Simple assault
# 4         1/1/20   0.0             Destruction, damage, vandalism
# ...          ...   ...                                        ...
# 498676  12/31/18  23.0                         Aggravated Assault
# 498677  12/31/18  23.0                Driving under the influence
# 498678  12/31/18  23.0                Driving under the influence
# 498679  12/31/18  23.0                  Drug, narcotic violations
# 498680  12/31/18  23.0                         Disorderly conduct
#
#         Offense_Count                               Premise Block_Range  \
# 0                 1.0  Residence, Home (Includes Apartment)        9311
# ...

# %%
import numpy as np

clean_crime_data_df['Street_Type'] = clean_crime_data_df['Street_Type'].replace(np.nan, '', regex=True)

clean_crime_data_df = clean_crime_data_df.astype(str)

clean_crime_data_df
# Out:
#             Date  Hour                               Offense_Type  \
# 0         1/1/20   0.0  Theft of motor vehicle parts or accessory
# 1         1/1/20   0.0                         Aggravated Assault
# 2         1/1/20   0.0             Destruction, damage, vandalism
# 3         1/1/20   0.0                             Simple assault
# 4         1/1/20   0.0             Destruction, damage, vandalism
# ...          ...   ...                                        ...
# 498676  12/31/18  23.0                         Aggravated Assault
# 498677  12/31/18  23.0                Driving under the influence
# 498678  12/31/18  23.0                Driving under the influence
# 498679  12/31/18  23.0                  Drug, narcotic violations
# 498680  12/31/18  23.0                         Disorderly conduct
#
#        Offense_Count                               Premise Block_Range  \
# 0                1.0  Residence, Home (Includes Apartment)        9311
# ...

# %%
clean_crime_data_df['Block_Range'] = clean_crime_data_df['Block_Range'].apply(lambda x: x.split('-')[0])
clean_crime_data_df
# Out:
#             Date  Hour                               Offense_Type  \
# 0         1/1/20   0.0  Theft of motor vehicle parts or accessory
# 1         1/1/20   0.0                         Aggravated Assault
# 2         1/1/20   0.0             Destruction, damage, vandalism
# 3         1/1/20   0.0                             Simple assault
# 4         1/1/20   0.0             Destruction, damage, vandalism
# ...          ...   ...                                        ...
# 498676  12/31/18  23.0                         Aggravated Assault
# 498677  12/31/18  23.0                Driving under the influence
# 498678  12/31/18  23.0                Driving under the influence
# 498679  12/31/18  23.0                  Drug, narcotic violations
# 498680  12/31/18  23.0                         Disorderly conduct
#
#        Offense_Count                               Premise Block_Range  \
# 0                1.0  Residence, Home (Includes Apartment)        9311
# ...

# %%
clean_crime_data_df['State'] = 'TX'
clean_crime_data_df.head()
# Out:
#      Date Hour                               Offense_Type Offense_Count  \
# 0  1/1/20  0.0  Theft of motor vehicle parts or accessory           1.0
# 1  1/1/20  0.0                         Aggravated Assault           1.0
# 2  1/1/20  0.0             Destruction, damage, vandalism           1.0
# 3  1/1/20  0.0                             Simple assault           1.0
# 4  1/1/20  0.0             Destruction, damage, vandalism           1.0
#
#                                 Premise Block_Range Street_Name Street_Type  \
# 0  Residence, Home (Includes Apartment)        9311  BELLA PINE          CT
# 1  Residence, Home (Includes Apartment)        8701     GUSTINE          LN
# 2  Residence, Home (Includes Apartment)        8064      LENORE
# 3  Residence, Home (Includes Apartment)        5930    DASHWOOD          DR
# 4  Residence, Home (Includes Apartment)        5218   KENILWOOD          DR
#
#       City State
# 0  HOUSTON    TX
# 1  HOUSTON    TX
# 2  HOUSTON    TX
# ...

# %%
clean_crime_data_df['Street_Address'] = clean_crime_data_df['Block_Range'] + ' ' + clean_crime_data_df['Street_Name'] + ' ' + clean_crime_data_df['Street_Type']

clean_crime_data_df
# Out:
#             Date  Hour                               Offense_Type  \
# 0         1/1/20   0.0  Theft of motor vehicle parts or accessory
# 1         1/1/20   0.0                         Aggravated Assault
# 2         1/1/20   0.0             Destruction, damage, vandalism
# 3         1/1/20   0.0                             Simple assault
# 4         1/1/20   0.0             Destruction, damage, vandalism
# ...          ...   ...                                        ...
# 498676  12/31/18  23.0                         Aggravated Assault
# 498677  12/31/18  23.0                Driving under the influence
# 498678  12/31/18  23.0                Driving under the influence
# 498679  12/31/18  23.0                  Drug, narcotic violations
# 498680  12/31/18  23.0                         Disorderly conduct
#
#        Offense_Count                               Premise Block_Range  \
# 0                1.0  Residence, Home (Includes Apartment)        9311
# ...

# %%
clean_crime_data_df['Zip_Code'] = ''
clean_crime_data_df
# Out:
#             Date  Hour                               Offense_Type  \
# 0         1/1/20   0.0  Theft of motor vehicle parts or accessory
# 1         1/1/20   0.0                         Aggravated Assault
# 2         1/1/20   0.0             Destruction, damage, vandalism
# 3         1/1/20   0.0                             Simple assault
# 4         1/1/20   0.0             Destruction, damage, vandalism
# ...          ...   ...                                        ...
# 498676  12/31/18  23.0                         Aggravated Assault
# 498677  12/31/18  23.0                Driving under the influence
# 498678  12/31/18  23.0                Driving under the influence
# 498679  12/31/18  23.0                  Drug, narcotic violations
# 498680  12/31/18  23.0                         Disorderly conduct
#
#        Offense_Count                               Premise Block_Range  \
# 0                1.0  Residence, Home (Includes Apartment)        9311
# ...

# %%
offense_types = clean_crime_data_df['Offense_Type'].to_list()
offense_types
# Out:
# ['Theft of motor vehicle parts or accessory',
#  'Aggravated Assault',
#  'Destruction, damage, vandalism',
#  'Simple assault',
#  'Destruction, damage, vandalism',
#  'Destruction, damage, vandalism',
#  'Destruction, damage, vandalism',
#  'Theft from motor vehicle',
#  'Simple assault',
#  'Simple assault',
#  'Destruction, damage, vandalism',
#  'Drug, narcotic violations',
#  'Aggravated Assault',
#  'Simple assault',
#  'Simple assault',
#  'Destruction, damage, vandalism',
#  'Simple assault',
#  'Intimidation',
#  'Intimidation',
#  'Destruction, damage, vandalism',
#  'Aggravated Assault',
#  'Robbery',
#  'Aggravated Assault',
#  'Simple assault',
#  'Forcible rape',
#  'Destruction, damage, vandalism',
#  'Motor vehicle theft',
#  'Destruction, damage, vandalism',
#  'Theft from motor vehicle',
#  'Motor vehicle theft',
#  'Destruction, damage, vandalism',
#  'Aggravated Assault',
#  'Destruction, damage, vandalism',
#  'Destruction, damage, vandalism',
# ...

# %%
offenses_list = ['Theft of motor vehicle parts or accessory', 'Human Trafficking/Commercial Sex Act', ''
 'Aggravated Assault', 'All other larceny', 'Burglary, Breaking and Entering', 'theft',
 'Destruction, damage, vandalism', 'assault', 'Negligent manslaughter', 'Pocket-picking', 'Purse-snatching', 
 'Simple assault', 'Intimidation', 'Robbery', 'Forcible rape', 'Theft from motor vehicle', 'Motor vehicle theft', 'Statutory rape', 'Murder, non-negligent', ] 
small_crime_data_df = clean_crime_data_df[clean_crime_data_df['Offense_Type'].isin(offenses_list)]
# clean_crime_data_df['Offense_Type'].value_counts()
small_crime_data_df.head()
# Out:
#      Date Hour                               Offense_Type Offense_Count  \
# 0  1/1/20  0.0  Theft of motor vehicle parts or accessory           1.0
# 1  1/1/20  0.0                         Aggravated Assault           1.0
# 2  1/1/20  0.0             Destruction, damage, vandalism           1.0
# 3  1/1/20  0.0                             Simple assault           1.0
# 4  1/1/20  0.0             Destruction, damage, vandalism           1.0
#
#                                 Premise Block_Range Street_Name Street_Type  \
# 0  Residence, Home (Includes Apartment)        9311  BELLA PINE          CT
# 1  Residence, Home (Includes Apartment)        8701     GUSTINE          LN
# 2  Residence, Home (Includes Apartment)        8064      LENORE
# 3  Residence, Home (Includes Apartment)        5930    DASHWOOD          DR
# 4  Residence, Home (Includes Apartment)        5218   KENILWOOD          DR
#
#       City State      Street_Address Zip_Code
# 0  HOUSTON    TX  9311 BELLA PINE CT
# ...

# %%
geo_df = small_crime_data_df[['Street_Address', 'City', 'State', 'Zip_Code']]

geo_df
# Out:
#                Street_Address     City State Zip_Code
# 0          9311 BELLA PINE CT  HOUSTON    TX
# 1             8701 GUSTINE LN  HOUSTON    TX
# 2                8064 LENORE   HOUSTON    TX
# 3            5930 DASHWOOD DR  HOUSTON    TX
# 4           5218 KENILWOOD DR  HOUSTON    TX
# ...                       ...      ...   ...      ...
# 498669         7700 AVENUE H   HOUSTON    TX
# 498670       7100 CULLEN BLVD  HOUSTON    TX
# 498671  10800 QUILL GARDEN LN  HOUSTON    TX
# 498672     16300 COVEY RUN DR  HOUSTON    TX
# 498676      3900 GRAPEVINE ST  HOUSTON    TX
#
# [353181 rows x 4 columns]

# %%
geo_df.to_csv('geo_csv.csv')

# %%
# import censusgeocode as cg
# import time
# from random_words import RandomWords
# import math

# rw = RandomWords()

# df_names = rw.random_words(count=100)

# k_list = []

# mylist = list(range(math.ceil(50000/500)))
# # print(mylist)

# # increments = [geo_df[0:20], geo_df[5000:9999], geo_df[10000:14999], geo_df[15000:19999], geo_df[20000:24999], geo_df[25000:29999], geo_df[30000:39999], geo_df[40000:44999], geo_df[45000:49999], geo_df[50000:54999], geo_df[550000:59999], geo_df[60000:64999], geo_df[65000:69999], geo_df[70000:74999], geo_df[75000:79999], geo_df[80000:84999], geo_df[85000:89999], geo_df[90000:94999], geo_df[95000:99999], geo_df[100000:104999], geo_df[105000:109999], geo_df[110000:114999], geo_df[1150000:119999], geo_df[120000:124999], geo_df[125000:129999], geo_df[130000:134999], geo_df[135000:139999], geo_df[140000:144999], geo_df[145000:149000], geo_df[150000:154999], geo_df[155000:159999], geo_df[160000:164999], geo_df[165000:169999], geo_df[170000:174999], geo_df[175000:179999], geo_df[180000:184999], geo_df[185000:189999], geo_df[190000:194999], geo_df[195000:199999], geo_df[200000:204999], geo_df[205000:209999], geo_df[210000:214999], geo_df[2150000:219999], geo_df[220000:224999], geo_df[225000:229999], geo_df[230000:234999], geo_df[235000:239999], geo_df[240000:244999], geo_df[245000:249000], geo_df[250000:254999], geo_df[255000:259999], geo_df[260000:264999], geo_df[265000:269999], geo_df[270000:274999], geo_df[275000:279999], geo_df[280000:284999], geo_df[285000:289999], geo_df[290000:294999], geo_df[295000:299999], geo_df[300000:304999], geo_df[305000:309999], geo_df[310000:314999], geo_df[3150000:319999], geo_df[320000:324999], geo_df[325000:329999], geo_df[330000:334999], geo_df[335000:339999], geo_df[340000:344999], geo_df[345000:349000], geo_df[350000:354999], geo_df[355000:359999], geo_df[360000:364999], geo_df[365000:369999], geo_df[370000:374999], geo_df[375000:379999], geo_df[380000:384999], geo_df[385000:389999], geo_df[390000:394999], geo_df[395000:399999], geo_df[400000:404999], geo_df[405000:409999], geo_df[410000:414999], geo_df[4150000:419999], geo_df[420000:424999], geo_df[425000:429999], geo_df[430000:434999], geo_df[435000:439999], geo_df[440000:444999], geo_df[445000:449000], geo_df[450000:454999], geo_df[455000:459999], geo_df[460000:464999], geo_df[465000:469999], geo_df[470000:474999], geo_df[475000:479999], geo_df[480000:484999], geo_df[485000:489999], geo_df[490000:494999], geo_df[495000:]]
# counter = 0
# start = 0
# end = 499

# for items in mylist:
#     geo_df[start:end].to_csv(f'crime{counter}.csv', header=False)
#     k = cg.addressbatch(f'crime{counter}.csv')
#     k_list.append(k)
#     if counter == 0:
#         df_names[int(f'{counter}')] = pd.DataFrame(k, columns=k[0].keys())
#     if counter > 0:
#         df_names[int(f'{counter}')] = pd.DataFrame(k, columns=k[0].keys())
#         df_names[int(f'{counter}')] = pd.concat([df_names[counter-1], df_names[counter]])
#         final_locations = (df_names[int(f'{counter}')])
#     print(counter)
#     counter+=1
#     start += 500
#     end += 500
#     time.sleep(30)

# %%
# final_locations['id'] = final_locations['id'].astype(int)
# final_locations.sort_values(by='id').head(50)

# %%
# This works, but doesn't give census tract at all

# import requests
# import csv
# import re

# def censusGeocode(file, output):
#     url = 'https://geocoding.geo.census.gov/geocoder/locations/addressbatch?form'
#     payload = {'benchmark':'Public_AR_Current', 'vintage':'Current_Current',}
#     files = {'addressFile': open(file)}
#     r = requests.post(url, files=files, data=payload)
#     results = str(r.text)
#     results = re.sub('"','',results)
#     results = results.split('\n')
#     with open(output, 'w', newline = '') as geocodeOutput:
#         w = csv.writer(geocodeOutput, delimiter=',')
#         w.writerows([c.strip() for c in r.split(',')] for r in results)
# censusGeocode('geo_csv_test.csv', 'geo_test_results.csv')

# %%
# geo_test_df = pd.read_csv('geo_test_results.csv')
# geo_test_df

# %%
geo_df['Street_Address'] = geo_df['Street_Address'].replace(' ', '+', regex=True)
geo_df['City'] = geo_df['City'].replace(' ', '+', regex=True)
geo_df['City'] = geo_df['City'].replace('HOUSTON', 'Houston', regex=True)
geo_df['Full_Address'] = geo_df['Street_Address'] + ', ' + geo_df['City'] + ', ' + geo_df['State']

geo_df
# Out:
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
address_list = geo_df['Street_Address'].to_list()
city_list = geo_df['City'].to_list()

print(len(address_list))
print(len(city_list))
# Out:
# 353181
# 353181

# %%
import requests
import csv

crime_lats = []
crime_lngs = []
census_tract = []

for street, city in zip(address_list[:75000], city_list[:75000]):
    try:
        census_url = f'https://geocoding.geo.census.gov/geocoder/geographies/address?street={street}&city={city}&state=TX&benchmark=Public_AR_Census2010&vintage=Census2010_Census2010&layers=14&format=json'
        response = requests.get(census_url)
        census_json = response.json()
        crime_lats.append(census_json['result']['addressMatches'][0]['coordinates']['y'])
        crime_lngs.append(census_json['result']['addressMatches'][0]['coordinates']['x'])
        census_tract.append(census_json['result']['addressMatches'][0]['geographies']['Census Blocks'][0]['TRACT'])
        print(f"{street} Latitude: {census_json['result']['addressMatches'][0]['coordinates']['y']}")
        print(f"{street} Longitude: {census_json['result']['addressMatches'][0]['coordinates']['x']}")
        print(f"{street} Census Tract: {census_json['result']['addressMatches'][0]['geographies']['Census Blocks'][0]['TRACT']}")
        print('-------------')                                        
    except:
        print(f'{street}: has failed you')

test_df = pd.DataFrame(crime_lats, columns=['Latitude'])
test_df['Longitude'] = crime_lngs
test_df['Census_Tract'] = census_tract

test_df.to_csv('first_set.csv', index=False)

# import censusgeocode as cg

# crime_lats = []
# crime_lngs = []
# census_tract_crime = []
# count = 1

# for address in address_list:
#     try:
#         this_address = cg.onelineaddress(address)
#         crime_lats.append(this_address[0]['coordinates']['y'])
#         crime_lngs.append(this_address[0]['coordinates']['x'])
#         census_tract_crime.append(this_address[0]['geographies']['2010 Census Blocks'][0]['TRACT'])
#         print(f'{count} - success')
#         count += 1
#     except:
#         crime_lats.append('NaN')
#         crime_lngs.append('NaN')
#         census_tract_crime.append('NaN') 
#         print(f'{count} - fail')
#         count += 1
# Out:
# 9311+BELLA+PINE+CT Latitude: 29.856216
# 9311+BELLA+PINE+CT Longitude: -95.252365
# 9311+BELLA+PINE+CT Census Tract: 231200
# -------------
# 8701+GUSTINE+LN Latitude: 29.669632
# 8701+GUSTINE+LN Longitude: -95.53044
# 8701+GUSTINE+LN Census Tract: 423202
# -------------
# 8064+LENORE+ Latitude: 29.67649
# 8064+LENORE+ Longitude: -95.26359
# 8064+LENORE+ Census Tract: 320602
# -------------
# 5930+DASHWOOD+DR Latitude: 29.707369
# 5930+DASHWOOD+DR Longitude: -95.48575
# 5930+DASHWOOD+DR Census Tract: 421403
# -------------
# 5218+KENILWOOD+DR Latitude: 29.672619
# 5218+KENILWOOD+DR Longitude: -95.344055
# 5218+KENILWOOD+DR Census Tract: 332000
# -------------
# 2851+WALLINGFORD+DR Latitude: 29.732677
# 2851+WALLINGFORD+DR Longitude: -95.56381
# 2851+WALLINGFORD+DR Census Tract: 452201
# -------------
# 16410+SKEET+CT: has failed you
# 400+80TH+ST Latitude: 29.731392
# 400+80TH+ST Longitude: -95.28147
# 400+80TH+ST Census Tract: 311100
# -------------
# ...

# %%
# from geopy.geocoders import Nominatim

# crime_lats = []
# crime_lngs = []

# for address in address_list:
#     try:
#         geolocator = Nominatim(user_agent="DreamTeam")
#         location = geolocator.geocode(address)
# #         print(location.raw)
#         print(f'{address} LatLng:{location.latitude, location.longitude}')
#         crime_lats.append(location.latitude)
#         crime_lngs.append(location.longitude)
#     except:
#         print('Not Found! :(')
#         crime_lats.append('NaN')
#         crime_lngs.append('NaN')
