# %%
import pandas as pd

# %%
latlng_df = pd.read_csv('revised_crimes_geo.csv')
latlng_df
# Out:
# /Users/ryanashcraft/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0      Date  Hour  Offense_Type  Offense_Count  \
# 0                0    1/1/20   0.0         Theft            1.0
# 1                1    1/1/20   0.0       Assault            1.0
# 2                2    1/1/20   0.0     Vandalism            1.0
# 3                3    1/1/20   0.0       Assault            1.0
# 4                4    1/1/20   0.0     Vandalism            1.0
# ...            ...       ...   ...           ...            ...
# 406479      498669  12/31/18  23.0     Vandalism            1.0
# 406480      498670  12/31/18  23.0  Intimidation            1.0
# 406481      498671  12/31/18  23.0       Assault            1.0
# 406482      498672  12/31/18  23.0       Assault            1.0
# ...

# %%
address_list = latlng_df['Full_Address'].to_list()

# %%
from geopy.geocoders import Nominatim

crime_lats = []
crime_lngs = []
counter = 0

for address in address_list[200000:250000]:
    try:
        geolocator = Nominatim(user_agent="DreamTeam")
        location = geolocator.geocode(address)
#         print(location.raw)
        print(f'{counter}:{address} LatLng:{location.latitude, location.longitude}')
        print('----------------')
        crime_lats.append(location.latitude)
        crime_lngs.append(location.longitude)
    except:
        print(f'{counter}:Not Found! :(')
        print('----------------')
        crime_lats.append('NaN')
        crime_lngs.append('NaN')
    counter+=1

latlng_florin = pd.DataFrame(crime_lats, columns=['Latitude'])
latlng_florin['Longitude'] = crime_lngs

latlng_florin.to_csv('LatLng5.csv', index=False)
# Out:
# 03363 MCCUE RD, Houston, TX LatLng:(29.729133, -95.464053)
# ----------------
# 114203 BATHURST DR, Houston, TX LatLng:(29.620827542146145, -95.43516282589977)
# ----------------
# 21528 OJEMAN RD, Houston, TX LatLng:(29.797760434343434, -95.5017428080808)
# ----------------
# 34321 GUESSENA , Houston, TX LatLng:(29.802827333360778, -95.24705691412645)
# ----------------
# 46808 BISSONNET ST, Houston, TX LatLng:(29.6896934, -95.5044425)
# ----------------
# 55916 GULFTON ST, Houston, TX LatLng:(29.716340846938774, -95.48489931632653)
# ----------------
# 69638 PLAINFIELD , Houston, TX LatLng:(29.675341666666668, -95.5461496969697)
# ----------------
# 7612 VICTORY DR, Houston, TX LatLng:(29.8697814, -95.4103306)
# ----------------
# 89630 MESA DR, Houston, TX LatLng:(29.810916, -95.261614)
# ----------------
# 911622 DOWNEY ST, Houston, TX LatLng:(29.869085181818182, -95.37510757575757)
# ----------------
# 1010910 GULF FWY, Houston, TX LatLng:(29.636439125, -95.23770143750001)
# ...
